# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path  # For defining dataset Paths
import sys                # For include librep package
sys.path.append("../..")

# Third party imports
import pandas as pd
import numpy as np

# Librep imports
from librep.utils.dataset import PandasDatasetsIO          # For quick load train, test and validation CSVs
from librep.datasets.multimodal import PandasMultiModalDataset # Wrap CSVs to librep's `Dataset` interface
# Out:
# 2022-10-18 10:00:53.290618: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-10-18 10:00:53.290646: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
from librep.utils.workflow import SimpleTrainEvalWorkflow, MultiRunWorkflow
from librep.estimators import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

from librep.metrics.report import ClassificationReport
import yaml

# %%
# Path for KuHar resampled to 20Hz view with the same activities (and labels numbers)
# It is assumed that the directory will contain (train.csv, test.csv and validation.csv)
dataset_path = Path("../../data/old-views/KuHar/resampled_view_20Hz")

# %%
# Kuhar dataframes
train, validation, test = PandasDatasetsIO(dataset_path).load()

# %%
train.head()
# Out:
#    Unnamed: 0  accel-x-0  accel-x-1  accel-x-2  accel-x-3  accel-x-4  \
# 0           0   0.001911  -0.014536   0.005845   0.003675  -0.014972
# 1           1   0.004114  -0.003186   0.000759   0.012450  -0.032074
# 2           2  -0.011282  -0.002432  -0.003199   0.008152  -0.021763
# 3           3  -0.009241  -0.004666   0.021606  -0.007200   0.003091
# 4           4  -0.013083  -0.005612   0.001645   0.006823  -0.004159
#
#    accel-x-5  accel-x-6  accel-x-7  accel-x-8  ...  accel-start-time  \
# 0   0.025607   0.000478  -0.031141  -0.014827  ...            23.235
# 1   0.007270  -0.000470   0.006980   0.021400  ...            56.292
# 2   0.000309  -0.004968  -0.009551   0.001497  ...            27.268
# 3   0.001630   0.005057  -0.008149   0.013167  ...            39.421
# 4   0.000415   0.008178   0.002637  -0.000827  ...            23.703
#
#    gyro-start-time  accel-end-time  gyro-end-time  activity code  length  \
# 0           23.223          26.260         26.249              0     300
# 1           56.292          59.245         59.245              0     300
# 2           27.267          30.290         30.291              0     300
# 3           39.420          42.441         42.440              0     300
# 4           23.703          26.656         26.656              0     300
#
#    serial  index  user  normalized activity code
# 0       1   2100  1051                         1
# 1       1   5700  1037                         1
# 2       1   2700  1075                         1
# 3       6   3900  1008                         1
# 4       1   2400  1038                         1
#
# [5 rows x 371 columns]

# %%
# Kuhar features to select
features = [
    "accel-x",
    "accel-y",
    "accel-z",
    "gyro-x",
    "gyro-y",
    "gyro-z"
]

# Creating the datasets

# Train
train_dataset = PandasMultiModalDataset(
    train,
    feature_prefixes=features,
    label_columns="activity code",
    as_array=True
)

# Validation
validation_dataset = PandasMultiModalDataset(
    validation,
    feature_prefixes=features,
    label_columns="activity code",
    as_array=True
)

# Test
test_dataset = PandasMultiModalDataset(
    test,
    feature_prefixes=features,
    label_columns="activity code",
    as_array=True
)

# %%
from librep.datasets.multimodal import TransformMultiModalDataset
from librep.transforms.fft import FFT

# %%
fft_transform = FFT(centered = True)
transformer = TransformMultiModalDataset(transforms=[fft_transform], new_window_name_prefix="fft.")

# %%
train_dataset_fft = transformer(train_dataset)
validation_dataset_fft = transformer(validation_dataset)
test_dataset_fft = transformer(test_dataset)

# %%
print(train_dataset_fft.X.shape)
print(validation_dataset_fft.X.shape)
print(test_dataset_fft.X.shape)
# Out:
# (3330, 180)
# (108, 180)
# (378, 180)

# %%
print(np.max(train_dataset_fft.X))
# Out:
# 1182.4630044066

# %%
train_dataset_fft.X
# Out:
# array([[2.08923330e-02, 1.12081089e-01, 6.03699767e-02, ...,
#         6.86907330e-03, 1.25349286e-02, 1.69158661e-02],
#        [1.53802877e-02, 8.24343989e-02, 4.18766153e-02, ...,
#         3.72912157e-03, 3.98584265e-03, 1.71193131e-02],
#        [5.21272671e-02, 4.82816195e-02, 8.93573044e-02, ...,
#         9.75422945e-03, 2.66463902e-02, 7.84359780e-03],
#        ...,
#        [2.46594280e+00, 2.97792077e+01, 2.58438841e+01, ...,
#         1.43625028e+00, 7.98405975e-01, 2.66617405e-01],
#        [3.12703194e+00, 2.12859482e+01, 9.31637610e+00, ...,
#         4.71804217e-01, 9.06413206e-01, 6.75740676e-01],
#        [1.48890233e+01, 6.63385820e+00, 8.58902995e+00, ...,
#         3.19953749e-01, 1.27100790e-01, 3.83110579e-01]])

# %%
train_HD = train_dataset_fft.X
train_LD = None
train_Y = train_dataset_fft.y
test_HD = test_dataset_fft.X
test_LD = None
test_Y = test_dataset_fft.y

# %% [markdown]
# # Applying Scaler

# %% [markdown]
# MinMaxScaler, MaxAbsScaler and StandardScaler apply the scaling PER FEATURE, which means the distance between points would actually be modified, and so, the ranking as well.
# Because of this, a new Scaler is used

# %%
from sklearn import preprocessing

scaler = preprocessing.MinMaxScaler()

# %%
train_HD = scaler.fit_transform(train_dataset_fft.X)
train_LD = None
# train_Y = train_dataset_fft.y
test_HD = scaler.fit_transform(test_dataset_fft.X)
test_LD = None
# test_Y = test_dataset_fft.y

# %%
np.min(train_HD), np.max(train_HD)
# Out:
# (0.0, 1.0000000000000002)

# %%
np.min(test_HD), np.max(test_HD)
# Out:
# (0.0, 1.0000000000000002)

# %% [markdown]
# # Reducing with Generic AE

# %% [markdown]
# The topological autoencoder can be used as a generic one by applying a lambda value of 0.

# %%
from librep.transforms.topo_ae import TopologicalDimensionalityReduction
from librep.estimators.ae.torch.models.topological_ae.topological_ae import TopologicallyRegularizedAutoencoder

kwargs = {'input_dims':180, 'custom_dim':2}
input_shape = (-1, 1, 180)
topoae_lambda = 0
topo_reducer = TopologicalDimensionalityReduction(
    ae_model='DeepAEforKuhar180ver2',
    lam = topoae_lambda,
    ae_kwargs = kwargs,
    input_shape = input_shape,
    patience=10
)
# Out:
# Topologically Regularized DeepAEforKuhar180ver2
# Using python to compute signatures
# DeepAEforKuhar180ver2, Input: 180 Inner dim: 2

# %%
title_plot = "KUHAR 20Hz\nTopoAE lambda " + str(topoae_lambda)
topo_reducer.fit(train_HD, train_Y, title_plot=title_plot)
# Out:
# Epoch:1, P:10, Loss:0.0059, Loss-ae:0.0059, Loss-topo:0.0295
# Epoch:2, P:10, Loss:0.0057, Loss-ae:0.0057, Loss-topo:0.0269
# Epoch:3, P:10, Loss:0.0040, Loss-ae:0.0040, Loss-topo:0.0126
# Epoch:4, P:10, Loss:0.0033, Loss-ae:0.0033, Loss-topo:0.0113
# Epoch:5, P:10, Loss:0.0031, Loss-ae:0.0031, Loss-topo:0.0153
# Epoch:6, P:10, Loss:0.0031, Loss-ae:0.0031, Loss-topo:0.0150
# Epoch:7, P:10, Loss:0.0027, Loss-ae:0.0027, Loss-topo:0.0133
# Epoch:8, P:10, Loss:0.0029, Loss-ae:0.0029, Loss-topo:0.0219
# Epoch:9, P:9, Loss:0.0025, Loss-ae:0.0025, Loss-topo:0.0141
# Epoch:10, P:10, Loss:0.0024, Loss-ae:0.0024, Loss-topo:0.0185
# Epoch:11, P:10, Loss:0.0025, Loss-ae:0.0025, Loss-topo:0.0363
# Epoch:12, P:9, Loss:0.0024, Loss-ae:0.0024, Loss-topo:0.0208
# Epoch:13, P:10, Loss:0.0022, Loss-ae:0.0022, Loss-topo:0.0411
# Epoch:14, P:10, Loss:0.0027, Loss-ae:0.0027, Loss-topo:0.0362
# Epoch:15, P:9, Loss:0.0024, Loss-ae:0.0024, Loss-topo:0.0303
# Epoch:16, P:8, Loss:0.0023, Loss-ae:0.0023, Loss-topo:0.0245
# Epoch:17, P:7, Loss:0.0023, Loss-ae:0.0023, Loss-topo:0.0206
# Epoch:18, P:6, Loss:0.0024, Loss-ae:0.0024, Loss-topo:0.0319
# Epoch:19, P:5, Loss:0.0022, Loss-ae:0.0022, Loss-topo:0.0265
# Epoch:20, P:10, Loss:0.0023, Loss-ae:0.0023, Loss-topo:0.0256
# Epoch:21, P:9, Loss:0.0023, Loss-ae:0.0023, Loss-topo:0.1155
# Epoch:22, P:8, Loss:0.0023, Loss-ae:0.0023, Loss-topo:0.0235
# Epoch:23, P:7, Loss:0.0023, Loss-ae:0.0023, Loss-topo:0.0298
# Epoch:24, P:6, Loss:0.0023, Loss-ae:0.0023, Loss-topo:0.0342
# Epoch:25, P:5, Loss:0.0022, Loss-ae:0.0022, Loss-topo:0.0348
# Epoch:26, P:4, Loss:0.0022, Loss-ae:0.0022, Loss-topo:0.0363
# Epoch:27, P:3, Loss:0.0029, Loss-ae:0.0029, Loss-topo:0.0648
# Epoch:28, P:2, Loss:0.0025, Loss-ae:0.0025, Loss-topo:0.1150
# Epoch:29, P:1, Loss:0.0025, Loss-ae:0.0025, Loss-topo:0.0404
# Epoch:30, P:0, Loss:0.0023, Loss-ae:0.0023, Loss-topo:0.0378

# %%
train_LD = np.reshape(topo_reducer.transform(train_HD), (-1,2))
print('TRAIN LD RESHAPED', train_LD.shape)
test_LD = np.reshape(topo_reducer.transform(test_HD), (-1,2))
print('TEST LD RESHAPED', test_LD.shape)
# Out:
# TRAIN LD RESHAPED (3330, 2)
# TEST LD RESHAPED (378, 2)

# %%
train_LD_pd = pd.DataFrame(train_LD)
train_LD_pd['y'] = train_Y
train_pmd = PandasMultiModalDataset(
    train_LD_pd,
    label_columns="y",
    as_array=True
)

test_LD_pd = pd.DataFrame(test_LD)
test_LD_pd['y'] = test_Y

test_pmd = PandasMultiModalDataset(
    test_LD_pd,
    label_columns="y",
    as_array=True
)

# %% [markdown]
# ## Set Reporter

# %%
reporter = ClassificationReport(
    use_accuracy=True, 
    use_f1_score=True,
    use_classification_report=False,
    use_confusion_matrix=False,
    plot_confusion_matrix=False
)

# %% [markdown]
# ## Experiment for Random Forest

# %%
experiment = SimpleTrainEvalWorkflow(
    estimator=RandomForestClassifier,
    estimator_creation_kwags ={'n_estimators':100} ,
    do_not_instantiate=False,
    do_fit=True,
    evaluator=reporter)

multi_run_experiment = MultiRunWorkflow(workflow=experiment, num_runs=10, debug=False)

# %%
result = multi_run_experiment(train_pmd, test_pmd)

# %%
accuracy = np.mean([run['result'][0]['accuracy'] for run in result['runs']])
f1 = np.mean([run['result'][0]['f1 score (weighted)'] for run in result['runs']])
print('ACCURACY', accuracy)
print('F1', f1)
# Out:
# ACCURACY 0.07724867724867726
# F1 0.11170728019075157

# %% [markdown]
# ## Experiment for SVC

# %%
experiment = SimpleTrainEvalWorkflow(
    estimator=SVC, 
    estimator_creation_kwags ={'C':3.0, 'kernel':"rbf"} ,
    do_not_instantiate=False, 
    do_fit=True,
    evaluator=reporter)

multi_run_experiment = MultiRunWorkflow(workflow=experiment, num_runs=1, debug=False)

# %%
result = multi_run_experiment(train_pmd, test_pmd)

# %%
accuracy = np.mean([run['result'][0]['accuracy'] for run in result['runs']])
f1 = np.mean([run['result'][0]['f1 score (weighted)'] for run in result['runs']])
print('ACCURACY', accuracy)
print('F1', f1)
# Out:
# ACCURACY 0.13756613756613756
# F1 0.1679404342284942

# %% [markdown]
# ## Experiment for KNN

# %%
experiment = SimpleTrainEvalWorkflow(
    estimator=KNeighborsClassifier,
    estimator_creation_kwags ={'n_neighbors' :1} ,
    do_not_instantiate=False,
    do_fit=True,
    evaluator=reporter
)

multi_run_experiment = MultiRunWorkflow(workflow=experiment, num_runs=1, debug=False)

# %%
result = multi_run_experiment(train_pmd, test_pmd)

# %%
accuracy = np.mean([run['result'][0]['accuracy'] for run in result['runs']])
f1 = np.mean([run['result'][0]['f1 score (weighted)'] for run in result['runs']])
print('ACCURACY', accuracy)
print('F1', f1)
# Out:
# ACCURACY 0.07407407407407407
# F1 0.10891004380195339

# %% [markdown]
# # Topological AE

# %%
from librep.transforms.topo_ae import TopologicalDimensionalityReduction
from librep.estimators.ae.torch.models.topological_ae.topological_ae import TopologicallyRegularizedAutoencoder
kwargs = {'input_dims':180, 'custom_dim':2}
input_shape = (-1, 1, 180)
topoae_lambda = 1
topo_reducer = TopologicalDimensionalityReduction(ae_model='DeepAEforKuhar180ver2', lam=topoae_lambda,
                                                      ae_kwargs=kwargs, input_shape=input_shape, patience=10)
# Out:
# Topologically Regularized DeepAEforKuhar180ver2
# Using python to compute signatures
# DeepAEforKuhar180ver2, Input: 180 Inner dim: 2

# %%
title_plot = "KUHAR 20Hz\nTopoAE lambda " + str(topoae_lambda)
topo_reducer.fit(train_HD, train_Y, title_plot=title_plot)
# Out:
# Epoch:1, P:10, Loss:0.0201, Loss-ae:0.0052, Loss-topo:0.0149
# Epoch:2, P:10, Loss:0.0086, Loss-ae:0.0039, Loss-topo:0.0047
# Epoch:3, P:10, Loss:0.0065, Loss-ae:0.0036, Loss-topo:0.0029
# Epoch:4, P:10, Loss:0.0103, Loss-ae:0.0027, Loss-topo:0.0076
# Epoch:5, P:9, Loss:0.0046, Loss-ae:0.0027, Loss-topo:0.0019
# Epoch:6, P:10, Loss:0.0044, Loss-ae:0.0025, Loss-topo:0.0019
# Epoch:7, P:10, Loss:0.0037, Loss-ae:0.0023, Loss-topo:0.0014
# Epoch:8, P:10, Loss:0.0050, Loss-ae:0.0023, Loss-topo:0.0027
# Epoch:9, P:9, Loss:0.0044, Loss-ae:0.0022, Loss-topo:0.0022
# Epoch:10, P:8, Loss:0.0060, Loss-ae:0.0024, Loss-topo:0.0036
# Epoch:11, P:7, Loss:0.0048, Loss-ae:0.0022, Loss-topo:0.0025
# Epoch:12, P:6, Loss:0.0173, Loss-ae:0.0025, Loss-topo:0.0148
# Epoch:13, P:5, Loss:0.0032, Loss-ae:0.0022, Loss-topo:0.0011
# Epoch:14, P:10, Loss:0.0048, Loss-ae:0.0021, Loss-topo:0.0027
# Epoch:15, P:9, Loss:0.0069, Loss-ae:0.0026, Loss-topo:0.0042
# Epoch:16, P:8, Loss:0.0041, Loss-ae:0.0020, Loss-topo:0.0021
# Epoch:17, P:7, Loss:0.0049, Loss-ae:0.0022, Loss-topo:0.0027
# Epoch:18, P:6, Loss:0.0034, Loss-ae:0.0021, Loss-topo:0.0013
# Epoch:19, P:5, Loss:0.0067, Loss-ae:0.0024, Loss-topo:0.0043
# Epoch:20, P:4, Loss:0.0114, Loss-ae:0.0023, Loss-topo:0.0092
# Epoch:21, P:3, Loss:0.0041, Loss-ae:0.0020, Loss-topo:0.0021
# Epoch:22, P:2, Loss:0.0057, Loss-ae:0.0023, Loss-topo:0.0034
# Epoch:23, P:1, Loss:0.0145, Loss-ae:0.0021, Loss-topo:0.0124
# Epoch:24, P:0, Loss:0.0079, Loss-ae:0.0024, Loss-topo:0.0055

# %%
train_LD = np.reshape(topo_reducer.transform(train_HD), (-1,2))
print('TRAIN LD RESHAPED', train_LD.shape)
test_LD = np.reshape(topo_reducer.transform(test_HD), (-1,2))
print('TEST LD RESHAPED', test_LD.shape)
# Out:
# TRAIN LD RESHAPED (3330, 2)
# TEST LD RESHAPED (378, 2)

# %%
train_LD_pd = pd.DataFrame(train_LD)
train_LD_pd['y'] = train_Y
train_pmd = PandasMultiModalDataset(
    train_LD_pd,
    label_columns="y",
    as_array=True
)

test_LD_pd = pd.DataFrame(test_LD)
test_LD_pd['y'] = test_Y

test_pmd = PandasMultiModalDataset(
    test_LD_pd,
    label_columns="y",
    as_array=True
)

# %% [markdown]
# ## Experiment for Random Forest

# %%
experiment = SimpleTrainEvalWorkflow(
    estimator=RandomForestClassifier,
    estimator_creation_kwags ={'n_estimators':100} ,
    do_not_instantiate=False,
    do_fit=True,
    evaluator=reporter)

multi_run_experiment = MultiRunWorkflow(workflow=experiment, num_runs=10, debug=False)

# %%
result = multi_run_experiment(train_pmd, test_pmd)

# %%
accuracy = np.mean([run['result'][0]['accuracy'] for run in result['runs']])
f1 = np.mean([run['result'][0]['f1 score (weighted)'] for run in result['runs']])
print('ACCURACY', accuracy)
print('F1', f1)
# Out:
# ACCURACY 0.17777777777777778
# F1 0.236331480743215

# %% [markdown]
# ## Experiment for SVC

# %%
experiment = SimpleTrainEvalWorkflow(
    estimator=SVC, 
    estimator_creation_kwags ={'C':3.0, 'kernel':"rbf"} ,
    do_not_instantiate=False, 
    do_fit=True,
    evaluator=reporter)

multi_run_experiment = MultiRunWorkflow(workflow=experiment, num_runs=1, debug=False)

# %%
result = multi_run_experiment(train_pmd, test_pmd)

# %%
accuracy = np.mean([run['result'][0]['accuracy'] for run in result['runs']])
f1 = np.mean([run['result'][0]['f1 score (weighted)'] for run in result['runs']])
print('ACCURACY', accuracy)
print('F1', f1)
# Out:
# ACCURACY 0.1984126984126984
# F1 0.24967641988819084

# %% [markdown]
# ## Experiment for KNN

# %%
experiment = SimpleTrainEvalWorkflow(
    estimator=KNeighborsClassifier,
    estimator_creation_kwags ={'n_neighbors' :1} ,
    do_not_instantiate=False,
    do_fit=True,
    evaluator=reporter
)

multi_run_experiment = MultiRunWorkflow(workflow=experiment, num_runs=1, debug=False)

# %%
result = multi_run_experiment(train_pmd, test_pmd)

# %%
accuracy = np.mean([run['result'][0]['accuracy'] for run in result['runs']])
f1 = np.mean([run['result'][0]['f1 score (weighted)'] for run in result['runs']])
print('ACCURACY', accuracy)
print('F1', f1)
# Out:
# ACCURACY 0.20634920634920634
# F1 0.26244295989910027

# %% [markdown]
# # Topological AE - Tanh

# %%
from librep.transforms.topo_ae import TopologicalDimensionalityReduction
from librep.estimators.ae.torch.models.topological_ae.topological_ae import TopologicallyRegularizedAutoencoder
kwargs = {'input_dims':180, 'custom_dim':2}
input_shape = (-1, 1, 180)
topoae_lambda = 1
topo_reducer = TopologicalDimensionalityReduction(ae_model='DeepAEforKuhar180ver3', lam=topoae_lambda,
                                                      ae_kwargs=kwargs, input_shape=input_shape, patience=10)
# Out:
# Topologically Regularized DeepAEforKuhar180ver3
# Using python to compute signatures
# DeepAEforKuhar180ver3, Input: 180 Inner dim: 2

# %%
title_plot = "KUHAR 20Hz\nTopoAE lambda " + str(topoae_lambda)
topo_reducer.fit(train_HD, train_Y, title_plot=title_plot)
# Out:
# Epoch:1, P:10, Loss:0.0248, Loss-ae:0.0046, Loss-topo:0.0201
# Epoch:2, P:10, Loss:0.0101, Loss-ae:0.0029, Loss-topo:0.0072
# Epoch:3, P:10, Loss:0.0060, Loss-ae:0.0028, Loss-topo:0.0032
# Epoch:4, P:10, Loss:0.0057, Loss-ae:0.0025, Loss-topo:0.0033
# Epoch:5, P:10, Loss:0.0060, Loss-ae:0.0024, Loss-topo:0.0036
# Epoch:6, P:9, Loss:0.0067, Loss-ae:0.0025, Loss-topo:0.0042
# Epoch:7, P:8, Loss:0.0073, Loss-ae:0.0027, Loss-topo:0.0047
# Epoch:8, P:7, Loss:0.0047, Loss-ae:0.0024, Loss-topo:0.0023
# Epoch:9, P:10, Loss:0.0071, Loss-ae:0.0024, Loss-topo:0.0047
# Epoch:10, P:9, Loss:0.0050, Loss-ae:0.0026, Loss-topo:0.0024
# Epoch:11, P:8, Loss:0.0054, Loss-ae:0.0025, Loss-topo:0.0029
# Epoch:12, P:7, Loss:0.0040, Loss-ae:0.0023, Loss-topo:0.0017
# Epoch:13, P:10, Loss:0.0082, Loss-ae:0.0022, Loss-topo:0.0060
# Epoch:14, P:9, Loss:0.0048, Loss-ae:0.0024, Loss-topo:0.0024
# Epoch:15, P:8, Loss:0.0137, Loss-ae:0.0022, Loss-topo:0.0115
# Epoch:16, P:7, Loss:0.0064, Loss-ae:0.0023, Loss-topo:0.0042
# Epoch:17, P:6, Loss:0.0070, Loss-ae:0.0023, Loss-topo:0.0047
# Epoch:18, P:5, Loss:0.0054, Loss-ae:0.0025, Loss-topo:0.0029
# Epoch:19, P:4, Loss:0.0034, Loss-ae:0.0021, Loss-topo:0.0013
# Epoch:20, P:10, Loss:0.0074, Loss-ae:0.0021, Loss-topo:0.0053
# Epoch:21, P:9, Loss:0.0043, Loss-ae:0.0019, Loss-topo:0.0023
# Epoch:22, P:8, Loss:0.0057, Loss-ae:0.0023, Loss-topo:0.0034
# Epoch:23, P:7, Loss:0.0055, Loss-ae:0.0020, Loss-topo:0.0035
# Epoch:24, P:6, Loss:0.0047, Loss-ae:0.0026, Loss-topo:0.0021
# Epoch:25, P:5, Loss:0.0036, Loss-ae:0.0022, Loss-topo:0.0014
# Epoch:26, P:4, Loss:0.0076, Loss-ae:0.0019, Loss-topo:0.0057
# Epoch:27, P:3, Loss:0.0059, Loss-ae:0.0020, Loss-topo:0.0039
# Epoch:28, P:2, Loss:0.0030, Loss-ae:0.0021, Loss-topo:0.0009
# Epoch:29, P:10, Loss:0.0034, Loss-ae:0.0020, Loss-topo:0.0014
# Epoch:30, P:9, Loss:0.0045, Loss-ae:0.0021, Loss-topo:0.0024
# Epoch:31, P:8, Loss:0.0081, Loss-ae:0.0024, Loss-topo:0.0057
# Epoch:32, P:7, Loss:0.0046, Loss-ae:0.0022, Loss-topo:0.0024
# Epoch:33, P:6, Loss:0.0071, Loss-ae:0.0025, Loss-topo:0.0046
# Epoch:34, P:5, Loss:0.0032, Loss-ae:0.0021, Loss-topo:0.0011
# Epoch:35, P:4, Loss:0.0041, Loss-ae:0.0021, Loss-topo:0.0020
# Epoch:36, P:3, Loss:0.0060, Loss-ae:0.0020, Loss-topo:0.0040
# Epoch:37, P:2, Loss:0.0041, Loss-ae:0.0021, Loss-topo:0.0020
# Epoch:38, P:1, Loss:0.0035, Loss-ae:0.0020, Loss-topo:0.0014
# Epoch:39, P:0, Loss:0.0045, Loss-ae:0.0022, Loss-topo:0.0023

# %%
train_LD = np.reshape(topo_reducer.transform(train_HD), (-1,2))
print('TRAIN LD RESHAPED', train_LD.shape)
test_LD = np.reshape(topo_reducer.transform(test_HD), (-1,2))
print('TEST LD RESHAPED', test_LD.shape)
# Out:
# TRAIN LD RESHAPED (3330, 2)
# TEST LD RESHAPED (378, 2)

# %%
train_LD_pd = pd.DataFrame(train_LD)
train_LD_pd['y'] = train_Y
train_pmd = PandasMultiModalDataset(
    train_LD_pd,
    label_columns="y",
    as_array=True
)

test_LD_pd = pd.DataFrame(test_LD)
test_LD_pd['y'] = test_Y

test_pmd = PandasMultiModalDataset(
    test_LD_pd,
    label_columns="y",
    as_array=True
)

# %% [markdown]
# ## Experiment for Random Forest

# %%
experiment = SimpleTrainEvalWorkflow(
    estimator=RandomForestClassifier,
    estimator_creation_kwags ={'n_estimators':100} ,
    do_not_instantiate=False,
    do_fit=True,
    evaluator=reporter)

multi_run_experiment = MultiRunWorkflow(workflow=experiment, num_runs=10, debug=False)

# %%
result = multi_run_experiment(train_pmd, test_pmd)

# %%
accuracy = np.mean([run['result'][0]['accuracy'] for run in result['runs']])
f1 = np.mean([run['result'][0]['f1 score (weighted)'] for run in result['runs']])
print('ACCURACY', accuracy)
print('F1', f1)
# Out:
# ACCURACY 0.1349206349206349
# F1 0.16967324035937453

# %% [markdown]
# ## Experiment for SVC

# %%
experiment = SimpleTrainEvalWorkflow(
    estimator=SVC, 
    estimator_creation_kwags ={'C':3.0, 'kernel':"rbf"} ,
    do_not_instantiate=False, 
    do_fit=True,
    evaluator=reporter)

multi_run_experiment = MultiRunWorkflow(workflow=experiment, num_runs=1, debug=False)

# %%
result = multi_run_experiment(train_pmd, test_pmd)

# %%
accuracy = np.mean([run['result'][0]['accuracy'] for run in result['runs']])
f1 = np.mean([run['result'][0]['f1 score (weighted)'] for run in result['runs']])
print('ACCURACY', accuracy)
print('F1', f1)
# Out:
# ACCURACY 0.17724867724867724
# F1 0.24892797688419477

# %% [markdown]
# ## Experiment for KNN

# %%
experiment = SimpleTrainEvalWorkflow(
    estimator=KNeighborsClassifier,
    estimator_creation_kwags ={'n_neighbors' :1} ,
    do_not_instantiate=False,
    do_fit=True,
    evaluator=reporter
)

multi_run_experiment = MultiRunWorkflow(workflow=experiment, num_runs=1, debug=False)

# %%
result = multi_run_experiment(train_pmd, test_pmd)

# %%
accuracy = np.mean([run['result'][0]['accuracy'] for run in result['runs']])
f1 = np.mean([run['result'][0]['f1 score (weighted)'] for run in result['runs']])
print('ACCURACY', accuracy)
print('F1', f1)
# Out:
# ACCURACY 0.1164021164021164
# F1 0.14792256118915703

# %% [markdown]
# # Reducing with UMAP

# %%
from librep.transforms import UMAP
umap_reducer = UMAP()
umap_reducer.fit(train_HD, train_Y)
# Out:
# UMAP(tqdm_kwds={'bar_format': '{desc}: {percentage:3.0f}%| {bar} {n_fmt}/{total_fmt} [{elapsed}]', 'desc': 'Epochs completed', 'disable': True})

# %%
train_LD = np.reshape(umap_reducer.transform(train_HD), (-1,2))
print('TRAIN LD RESHAPED', train_LD.shape)
test_LD = np.reshape(umap_reducer.transform(test_HD), (-1,2))
print('TEST LD RESHAPED', test_LD.shape)
# Out:
# TRAIN LD RESHAPED (3330, 2)
# TEST LD RESHAPED (378, 2)

# %%
train_LD_pd = pd.DataFrame(train_LD)
train_LD_pd['y'] = train_Y
train_pmd = PandasMultiModalDataset(
    train_LD_pd,
    label_columns="y",
    as_array=True
)

test_LD_pd = pd.DataFrame(test_LD)
test_LD_pd['y'] = test_Y

test_pmd = PandasMultiModalDataset(
    test_LD_pd,
    label_columns="y",
    as_array=True
)

# %% [markdown]
# ## Experiment for Random Forest

# %%
experiment = SimpleTrainEvalWorkflow(
    estimator=RandomForestClassifier,
    estimator_creation_kwags ={'n_estimators':100} ,
    do_not_instantiate=False,
    do_fit=True,
    evaluator=reporter)

multi_run_experiment = MultiRunWorkflow(workflow=experiment, num_runs=10, debug=False)

# %%
result = multi_run_experiment(train_pmd, test_pmd)

# %%
accuracy = np.mean([run['result'][0]['accuracy'] for run in result['runs']])
f1 = np.mean([run['result'][0]['f1 score (weighted)'] for run in result['runs']])
print('ACCURACY', accuracy)
print('F1', f1)
# Out:
# ACCURACY 0.5608465608465608
# F1 0.5850562286419025

# %% [markdown]
# ## Experiment for SVC

# %%
experiment = SimpleTrainEvalWorkflow(
    estimator=SVC, 
    estimator_creation_kwags ={'C':3.0, 'kernel':"rbf"} ,
    do_not_instantiate=False, 
    do_fit=True,
    evaluator=reporter)

multi_run_experiment = MultiRunWorkflow(workflow=experiment, num_runs=1, debug=False)

# %%
result = multi_run_experiment(train_pmd, test_pmd)

# %%
accuracy = np.mean([run['result'][0]['accuracy'] for run in result['runs']])
f1 = np.mean([run['result'][0]['f1 score (weighted)'] for run in result['runs']])
print('ACCURACY', accuracy)
print('F1', f1)
# Out:
# ACCURACY 0.5608465608465608
# F1 0.5855126761311902

# %% [markdown]
# ## Experiment for KNN

# %%
experiment = SimpleTrainEvalWorkflow(
    estimator=KNeighborsClassifier,
    estimator_creation_kwags ={'n_neighbors' :1} ,
    do_not_instantiate=False,
    do_fit=True,
    evaluator=reporter
)

multi_run_experiment = MultiRunWorkflow(workflow=experiment, num_runs=1, debug=False)

# %%
result = multi_run_experiment(train_pmd, test_pmd)

# %%
accuracy = np.mean([run['result'][0]['accuracy'] for run in result['runs']])
f1 = np.mean([run['result'][0]['f1 score (weighted)'] for run in result['runs']])
print('ACCURACY', accuracy)
print('F1', f1)
# Out:
# ACCURACY 0.5555555555555556
# F1 0.5806224173211203

# %%
assert 1==0
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [71], in <cell line: 1>()
# ----> 1 assert 1==0
#
# AssertionError:

# %%
test_applied_topoae = transform_topoae.transform(test_dataset_fft.X)
print('ORIGINAL', test_applied_topoae.shape)
test_applied_topoae = np.reshape(test_applied_topoae, (-1,2))
print('RESHAPED', test_applied_topoae.shape)

# %%
train_applied_topoae = transform_topoae.transform(train_dataset_fft.X)
print('ORIGINAL', train_applied_topoae.shape)
train_applied_topoae = np.reshape(train_applied_topoae, (-1,2))
print('RESHAPED', train_applied_topoae.shape)

# %%
from librep.transforms import TSNE
import numpy as np
import matplotlib.pyplot as plt

def visualize(X, Y, filtered=None, xlim=None, ylim=None):
    data_grouped = list(zip(X, Y))
    uniques = filtered
    if filtered is None:
        uniques = np.unique(Y)
    
    for uval in uniques:
        data = [pair[0] for pair in data_grouped if pair[1]==uval]
        data_x = [unit[0] for unit in data]
        data_y = [unit[1] for unit in data]
        plt.scatter(data_x, data_y, label = uval)
    # print(data)
    if xlim:
        plt.xlim(xlim)
    if ylim:
        plt.ylim(ylim)
    plt.grid()
    plt.legend()
    plt.show()

# %%
visualize(test_applied_topoae, test_dataset_fft.y)

# %%
# filtered
filter_to_use = [0,1,2,3,4,5]
visualize(test_applied_topoae, test_dataset_fft.y, filtered=filter_to_use, xlim=(-1,0), ylim=(-0.5,1.75))
for f in filter_to_use:
    visualize(test_applied_topoae, test_dataset_fft.y, filtered=[f], xlim=(-1,0), ylim=(-0.5,1.75))
# visualize(test_applied_topoae, test_dataset_fft.y, filtered=[1])
# 0 sit
# 1 stand
# 2 walk
# 3 stair up
# 4 stair down
# 5 run

# %%
from librep.metrics.dimred_evaluator import DimensionalityReductionQualityReport
metrics_reporter = DimensionalityReductionQualityReport()
metrics_train_applied_topoae = metrics_reporter.evaluate([test_dataset_fft.X, test_applied_topoae])
print(metrics_train_applied_topoae)

# %%
from librep.utils.workflow import SimpleTrainEvalWorkflow, MultiRunWorkflow
from librep.estimators import RandomForestClassifier
from librep.metrics.report import ClassificationReport
import yaml

reporter = ClassificationReport(use_accuracy=True, use_f1_score=True, use_classification_report=False, use_confusion_matrix=False, plot_confusion_matrix=False)
experiment = SimpleTrainEvalWorkflow(estimator=RandomForestClassifier, estimator_creation_kwags ={'n_estimators':100} , do_not_instantiate=False, do_fit=True, evaluator=reporter)
multi_run_experiment = MultiRunWorkflow(workflow=experiment, num_runs=3, debug=False)

# %%
combined_train_dset = PandasMultiModalDataset(
    pd.concat([train, validation]),
    feature_prefixes=features,
    label_columns="activity code",
    as_array=True
)


result = multi_run_experiment(combined_train_dset, test_dataset)
print(yaml.dump(result, sort_keys=True, indent=4))

# %%
combined_train_dset_fft = transformer(combined_train_dset)

result = multi_run_experiment(combined_train_dset_fft, test_dataset_fft)
print(yaml.dump(result, sort_keys=True, indent=4))

# %%
print(train_dataset_fft.y)

print(combined_train_dset.data.shape)

# %%
import pandas as pd

# Using the latent space
train_applied_topoae = transform_topoae.transform(train_dataset_fft.X)
print('ORIGINAL', train_applied_topoae.shape)
train_applied_topoae = np.reshape(train_applied_topoae, (-1,2))
print('RESHAPED', train_applied_topoae.shape)

train_applied_topoae_pd = pd.DataFrame(train_applied_topoae)
train_applied_topoae_pd['y'] = train_dataset_fft.y
# print('FINAL', train_applied_topoae_pd)


topoae_train_dset = PandasMultiModalDataset(
    train_applied_topoae_pd,
    label_columns="y",
    as_array=True
)

test_applied_topoae_pd = pd.DataFrame(test_applied_topoae)
test_applied_topoae_pd['y'] = test_dataset_fft.y
# print('FINAL', test_applied_topoae_pd)

topoae_test_dset = PandasMultiModalDataset(
    test_applied_topoae_pd,
    label_columns="y",
    as_array=True
)
result = multi_run_experiment(topoae_train_dset, topoae_test_dset)
print(yaml.dump(result, sort_keys=True, indent=4))

# %% [markdown]
# # SVC

# %%
result = multi_run_experiment(topoae_train_dset, topoae_test_dset)
print(yaml.dump(result, sort_keys=True, indent=4))

# %%
result = multi_run_experiment(topoae_train_dset, topoae_test_dset)
print(yaml.dump(result, sort_keys=True, indent=4))

# %%
data = [[-1, 2], [0, 2], [0, 3], [1, 4]]
data = [[-1, 2, 0, 2, 0, 3, 1, 5], [-1, 2, 0, 2, 0, 3, 1, 4]]

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import StandardScaler


scaler = MinMaxScaler().fit(data)
print("MINMAX\n", scaler.transform(data))
scaler = MaxAbsScaler().fit(data)
print("MAXABS\n", scaler.transform(data))
scaler = StandardScaler().fit(data)
print("STANDARD\n", scaler.transform(data))

# %%
X = [[ 1., -1.,  2.],
     [ 2.,  0.,  0.],
     [ 0.,  1., -1.]]
transformer = MaxAbsScaler().fit(X)
transformer

transformer.transform(X)

# %%
data = [[0, 0], [0, 0], [1, 1], [1, 1]]
print(scaler.fit(data))

print(scaler.mean_)

print(scaler.transform(data))




print(scaler.transform([[2, 2]]))
