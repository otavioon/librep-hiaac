# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../../..")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from librep.datasets.har.loaders import (
    MotionSense_BalancedView20HZ
)
# Out:
# 2022-11-16 01:25:15.491715: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-11-16 01:25:15.506827: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
from librep.transforms.topo_ae import (
    TopologicalDimensionalityReduction,
    CustomTopoDimRedTransform
)
from librep.transforms import UMAP
from sklearn.manifold import TSNE
from experiments.Topological_ae.Experiment_utils import *
from librep.datasets.multimodal import TransformMultiModalDataset
from librep.transforms.fft import FFT

# %%
# MotionSense Loader
loader = MotionSense_BalancedView20HZ(
    root_dir="../../../data/views/MotionSense/balanced_view_20Hz_with_gravity_9.81_acc_standard", 
    download=False
)

# Print the readme (optional)
loader.print_readme()
# Out:
# # Balanced MotionSense View Resampled to 20Hz with Gravity - Multiplied acc by 9.81m/s²
#
# This is a view from [MotionSense] that was spllited into 3s windows and was resampled to 20Hz using the [FFT method](https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.resample.html#scipy.signal.resample).
#
# The data was first splitted in three sets: train, validation and test. Each one with the following proportions:
# - Train: 70% of samples
# - Validation: 10% of samples
# - Test: 20% of samples
#
# After splits, the datasets were balanced in relation to the activity code column, that is, each subset have the same number of activitiy samples.
#
# **NOTE**: Each subset contain samples from distinct users, that is, samples of one user belongs exclusivelly to one of three subsets.
#
# ## Activity codes
# - 0: downstairs (569 train, 101 validation, 170 test)
# - 1: upstairs (569 train, 101 validation, 170 test)
# - 2: sitting (569 train, 101 validation, 170 test)
# - 3: standing (569 train, 101 validation, 170 test)
# - 4: walking (569 train, 101 validation, 170 test)
# - 5: jogging (569 train, 101 validation, 170 test)
#
#
# ## Standartized activity codes
# - 0: sit (569 train, 101 validation, 170 test)
# - 1: stand (569 train, 101 validation, 170 test)
# - 2: walk (569 train, 101 validation, 170 test)
# - 3: stair up (569 train, 101 validation, 170 test)
# - 4: stair down (569 train, 101 validation, 170 test)
# - 5: run (569 train, 101 validation, 170 test)

# %%
# Load the dataset
# If concat_train_validation is true, return a tuple (train+validation, test)
train_val, test = loader.load(concat_train_validation=True, label=loader.standard_label)
train_val, test
# Out:
# (PandasMultiModalDataset: samples=4020, features=360, no. window=6, label_columns='standard activity code',
#  PandasMultiModalDataset: samples=1020, features=360, no. window=6, label_columns='standard activity code')

# %%
train_HD = np.array(train_val[:][0])
train_Y = np.array(train_val[:][1])
test_HD = np.array(test[:][0])
test_Y = np.array(test[:][1])

# %%
print(train_HD.shape, train_Y.shape, test_HD.shape, test_Y.shape)
# Out:
# (4020, 360) (4020,) (1020, 360) (1020,)

# %% [markdown]
# # Aplicar FFT

# %%
fft_transform = FFT(centered = True)
transformer = TransformMultiModalDataset(
    transforms=[fft_transform],
    new_window_name_prefix="fft."
)

# %%
train_dataset_fft = transformer(train_val)
test_dataset_fft = transformer(test)

# %%
print(train_dataset_fft.X.shape)
print(test_dataset_fft.X.shape)
# Out:
# (4020, 180)
# (1020, 180)

# %%
print(np.max(train_dataset_fft.X))
# Out:
# 797.3368276806895

# %%
train_HD = train_dataset_fft.X
train_LD = None
train_Y = train_dataset_fft.y
test_HD = test_dataset_fft.X
test_LD = None
test_Y = test_dataset_fft.y

# %%
print(train_HD.shape, train_Y.shape, test_HD.shape, test_Y.shape)
# Out:
# (4020, 180) (4020,) (1020, 180) (1020,)

# %% [markdown]
# # Visualization helper

# %%
# 0: sit (569 train, 101 validation, 170 test)
# 1: stand (569 train, 101 validation, 170 test)
# 2: walk (569 train, 101 validation, 170 test)
# 3: stair up (569 train, 101 validation, 170 test)
# 4: stair down (569 train, 101 validation, 170 test)
# 5: run (569 train, 101 validation, 170 test)
def visualize(X, Y):
    labels = ['sit', 'stand', 'walk', 'stair up', 'stair down', 'run']
    df = pd.DataFrame(dict(x=X[:,0], y=X[:,1], label=Y))
    groups = df.groupby('label')
    fig, ax = plt.subplots()
    ax.margins(0.05)
    for name, group in groups:
        ax.plot(group.x, group.y, marker='.', linestyle='', ms=8, label=labels[name])
    # Shrink current axis by 20%
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])

    # Put a legend to the right of the current axis
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.show()

# %%
# Variables to reuse
model_dim = 10
model_epc = 125

# %% [markdown]
# # Reducing with Convolutional Topological Autoencoders

# %%
model_lam = 1
model_dim = 10
model_epc = 1500
topo_reducer = TopologicalDimensionalityReduction(
    ae_model='ConvolutionalAutoencoder_custom_dim2',
    lam = model_lam,
    ae_kwargs = {'input_dims':(1, 180), 'custom_dim':model_dim},
    input_shape = (-1, 1, 1, 180),
    patience = None,
    num_epochs = model_epc
)
# Out:
# Topologically Regularized ConvolutionalAutoencoder_custom_dim2
# Using python to compute signatures
# ConvAECustomDim, Input: (1, 180) Inner dim: 10
# ENCODER STRUCT torch.Size([4, 8, 5])

# %%
model_lam = 1
topo_reducer = CustomTopoDimRedTransform(
    model_name='ConvolutionalAutoencoder_custom_dim2',
    model_lambda=model_lam,
    patience=None,
    num_epochs=model_epc,
    from_dim=180,
    to_dim=model_dim
)
# Out:
# Topologically Regularized ConvolutionalAutoencoder_custom_dim2
# Using python to compute signatures
# ConvAECustomDim, Input: (1, 180) Inner dim: 10
# ENCODER STRUCT torch.Size([4, 8, 5])

# %%
title_plot = "MotionSense 20Hz\nTopoAE lambda {}".format(model_lam)
topo_reducer.fit(train_HD, train_Y, title_plot=title_plot)
# Out:
# Epoch:1, P:None, Loss:2624.0276, Loss-ae:2624.0241, Loss-topo:0.0035
# Epoch:2, P:None, Loss:2600.2223, Loss-ae:2600.2214, Loss-topo:0.0009
# Epoch:3, P:None, Loss:2626.3529, Loss-ae:2626.3523, Loss-topo:0.0005
# Epoch:4, P:None, Loss:2609.7589, Loss-ae:2609.7581, Loss-topo:0.0008
# Epoch:5, P:None, Loss:2585.0352, Loss-ae:2585.0347, Loss-topo:0.0004
# Epoch:6, P:None, Loss:2598.1977, Loss-ae:2598.1973, Loss-topo:0.0005
# Epoch:7, P:None, Loss:2600.7626, Loss-ae:2600.7621, Loss-topo:0.0005
# Epoch:8, P:None, Loss:2598.1048, Loss-ae:2598.1045, Loss-topo:0.0003
# Epoch:9, P:None, Loss:2608.4386, Loss-ae:2608.4382, Loss-topo:0.0004
# Epoch:10, P:None, Loss:2617.4070, Loss-ae:2617.4064, Loss-topo:0.0007
# Epoch:11, P:None, Loss:2591.6142, Loss-ae:2591.6137, Loss-topo:0.0005
# Epoch:12, P:None, Loss:2603.3578, Loss-ae:2603.3574, Loss-topo:0.0005
# Epoch:13, P:None, Loss:2577.6387, Loss-ae:2577.6381, Loss-topo:0.0006
# Epoch:14, P:None, Loss:2595.8964, Loss-ae:2595.8960, Loss-topo:0.0004
# Epoch:15, P:None, Loss:2602.8425, Loss-ae:2602.8420, Loss-topo:0.0005
# Epoch:16, P:None, Loss:2615.6145, Loss-ae:2615.6139, Loss-topo:0.0006
# Epoch:17, P:None, Loss:2604.2236, Loss-ae:2604.2233, Loss-topo:0.0004
# Epoch:18, P:None, Loss:2603.1242, Loss-ae:2603.1238, Loss-topo:0.0004
# Epoch:19, P:None, Loss:2577.4887, Loss-ae:2577.4883, Loss-topo:0.0003
# Epoch:20, P:None, Loss:2587.1211, Loss-ae:2587.1204, Loss-topo:0.0007
# Epoch:21, P:None, Loss:2613.6072, Loss-ae:2613.6068, Loss-topo:0.0005
# Epoch:22, P:None, Loss:2622.2441, Loss-ae:2622.2434, Loss-topo:0.0008
# Epoch:23, P:None, Loss:2597.1009, Loss-ae:2597.1005, Loss-topo:0.0004
# Epoch:24, P:None, Loss:2622.7721, Loss-ae:2622.7717, Loss-topo:0.0005
# Epoch:25, P:None, Loss:2576.5641, Loss-ae:2576.5638, Loss-topo:0.0003
# Epoch:26, P:None, Loss:2618.9805, Loss-ae:2618.9800, Loss-topo:0.0004
# Epoch:27, P:None, Loss:2600.6416, Loss-ae:2600.6411, Loss-topo:0.0005
# Epoch:28, P:None, Loss:2601.4069, Loss-ae:2601.4065, Loss-topo:0.0003
# Epoch:29, P:None, Loss:2598.6755, Loss-ae:2598.6749, Loss-topo:0.0007
# Epoch:30, P:None, Loss:2612.3259, Loss-ae:2612.3256, Loss-topo:0.0003
# Epoch:31, P:None, Loss:2589.4461, Loss-ae:2589.4457, Loss-topo:0.0005
# Epoch:32, P:None, Loss:2623.9655, Loss-ae:2623.9650, Loss-topo:0.0005
# Epoch:33, P:None, Loss:2613.7064, Loss-ae:2613.7054, Loss-topo:0.0010
# Epoch:34, P:None, Loss:2591.5782, Loss-ae:2591.5779, Loss-topo:0.0003
# Epoch:35, P:None, Loss:2616.5863, Loss-ae:2616.5858, Loss-topo:0.0005
# Epoch:36, P:None, Loss:2582.1264, Loss-ae:2582.1259, Loss-topo:0.0005
# Epoch:37, P:None, Loss:2609.7788, Loss-ae:2609.7783, Loss-topo:0.0005
# Epoch:38, P:None, Loss:2595.3190, Loss-ae:2595.3186, Loss-topo:0.0004
# Epoch:39, P:None, Loss:2595.3823, Loss-ae:2595.3818, Loss-topo:0.0005
# Epoch:40, P:None, Loss:2609.7520, Loss-ae:2609.7514, Loss-topo:0.0006
# Epoch:41, P:None, Loss:2632.6856, Loss-ae:2632.6851, Loss-topo:0.0005
# Epoch:42, P:None, Loss:2610.2789, Loss-ae:2610.2786, Loss-topo:0.0003
# Epoch:43, P:None, Loss:2602.5535, Loss-ae:2602.5532, Loss-topo:0.0003
# Epoch:44, P:None, Loss:2595.7809, Loss-ae:2595.7804, Loss-topo:0.0004
# Epoch:45, P:None, Loss:2621.6311, Loss-ae:2621.6301, Loss-topo:0.0010
# Epoch:46, P:None, Loss:2582.3378, Loss-ae:2582.3374, Loss-topo:0.0004
# Epoch:47, P:None, Loss:2615.1529, Loss-ae:2615.1526, Loss-topo:0.0004
# Epoch:48, P:None, Loss:2592.0479, Loss-ae:2592.0473, Loss-topo:0.0006
# Epoch:49, P:None, Loss:2613.3125, Loss-ae:2613.3119, Loss-topo:0.0005
# Epoch:50, P:None, Loss:2607.4860, Loss-ae:2607.4857, Loss-topo:0.0003
# Epoch:51, P:None, Loss:2598.6071, Loss-ae:2598.6068, Loss-topo:0.0003
# Epoch:52, P:None, Loss:2599.0176, Loss-ae:2599.0173, Loss-topo:0.0003
# Epoch:53, P:None, Loss:2594.5207, Loss-ae:2594.5203, Loss-topo:0.0004
# Epoch:54, P:None, Loss:2611.8051, Loss-ae:2611.8045, Loss-topo:0.0006
# Epoch:55, P:None, Loss:2578.2723, Loss-ae:2578.2709, Loss-topo:0.0013
# Epoch:56, P:None, Loss:2595.4281, Loss-ae:2595.4272, Loss-topo:0.0009
# Epoch:57, P:None, Loss:2602.5982, Loss-ae:2602.5978, Loss-topo:0.0004
# Epoch:58, P:None, Loss:2567.7223, Loss-ae:2567.7216, Loss-topo:0.0006
# Epoch:59, P:None, Loss:2580.7385, Loss-ae:2580.7380, Loss-topo:0.0005
# Epoch:60, P:None, Loss:2580.8514, Loss-ae:2580.8507, Loss-topo:0.0007
# Epoch:61, P:None, Loss:2609.7634, Loss-ae:2609.7628, Loss-topo:0.0005
# Epoch:62, P:None, Loss:2597.6032, Loss-ae:2597.6027, Loss-topo:0.0005
# Epoch:63, P:None, Loss:2607.0942, Loss-ae:2607.0939, Loss-topo:0.0004
# Epoch:64, P:None, Loss:2589.6562, Loss-ae:2589.6553, Loss-topo:0.0009
# Epoch:65, P:None, Loss:2627.4883, Loss-ae:2627.4877, Loss-topo:0.0006
# Epoch:66, P:None, Loss:2589.5362, Loss-ae:2589.5357, Loss-topo:0.0005
# Epoch:67, P:None, Loss:2595.3947, Loss-ae:2595.3940, Loss-topo:0.0007
# Epoch:68, P:None, Loss:2589.0651, Loss-ae:2589.0646, Loss-topo:0.0005
# Epoch:69, P:None, Loss:2580.4163, Loss-ae:2580.4153, Loss-topo:0.0010
# Epoch:70, P:None, Loss:2607.3821, Loss-ae:2607.3812, Loss-topo:0.0008
# Epoch:71, P:None, Loss:2604.8283, Loss-ae:2604.8277, Loss-topo:0.0006
# Epoch:72, P:None, Loss:2585.0749, Loss-ae:2585.0742, Loss-topo:0.0006
# Epoch:73, P:None, Loss:2575.8812, Loss-ae:2575.8808, Loss-topo:0.0005
# Epoch:74, P:None, Loss:2575.8910, Loss-ae:2575.8906, Loss-topo:0.0004
# Epoch:75, P:None, Loss:2602.7826, Loss-ae:2602.7822, Loss-topo:0.0003
# Epoch:76, P:None, Loss:2612.8166, Loss-ae:2612.8162, Loss-topo:0.0004
# Epoch:77, P:None, Loss:2625.4573, Loss-ae:2625.4569, Loss-topo:0.0005
# Epoch:78, P:None, Loss:2587.1862, Loss-ae:2587.1859, Loss-topo:0.0003
# Epoch:79, P:None, Loss:2616.3282, Loss-ae:2616.3279, Loss-topo:0.0003
# Epoch:80, P:None, Loss:2575.1173, Loss-ae:2575.1167, Loss-topo:0.0005
# Epoch:81, P:None, Loss:2594.8443, Loss-ae:2594.8438, Loss-topo:0.0006
# Epoch:82, P:None, Loss:2634.1830, Loss-ae:2634.1825, Loss-topo:0.0006
# Epoch:83, P:None, Loss:2624.6248, Loss-ae:2624.6243, Loss-topo:0.0004
# Epoch:84, P:None, Loss:2590.5055, Loss-ae:2590.5051, Loss-topo:0.0004
# Epoch:85, P:None, Loss:2629.4212, Loss-ae:2629.4209, Loss-topo:0.0003
# Epoch:86, P:None, Loss:2611.6414, Loss-ae:2611.6409, Loss-topo:0.0004
# Epoch:87, P:None, Loss:2586.5872, Loss-ae:2586.5867, Loss-topo:0.0004
# Epoch:88, P:None, Loss:2600.6402, Loss-ae:2600.6399, Loss-topo:0.0003
# Epoch:89, P:None, Loss:2611.5694, Loss-ae:2611.5687, Loss-topo:0.0006
# Epoch:90, P:None, Loss:2597.6850, Loss-ae:2597.6843, Loss-topo:0.0007
# Epoch:91, P:None, Loss:2601.5586, Loss-ae:2601.5581, Loss-topo:0.0005
# Epoch:92, P:None, Loss:2617.5857, Loss-ae:2617.5851, Loss-topo:0.0006
# Epoch:93, P:None, Loss:2595.9774, Loss-ae:2595.9771, Loss-topo:0.0003
# Epoch:94, P:None, Loss:2576.3148, Loss-ae:2576.3145, Loss-topo:0.0003
# Epoch:95, P:None, Loss:2584.6613, Loss-ae:2584.6608, Loss-topo:0.0004
# Epoch:96, P:None, Loss:2597.0396, Loss-ae:2597.0392, Loss-topo:0.0004
# Epoch:97, P:None, Loss:2604.6905, Loss-ae:2604.6900, Loss-topo:0.0005
# Epoch:98, P:None, Loss:2617.2641, Loss-ae:2617.2634, Loss-topo:0.0006
# Epoch:99, P:None, Loss:2596.4901, Loss-ae:2596.4896, Loss-topo:0.0004
# Epoch:100, P:None, Loss:2627.8790, Loss-ae:2627.8785, Loss-topo:0.0006
# Epoch:101, P:None, Loss:2613.0584, Loss-ae:2613.0573, Loss-topo:0.0011
# Epoch:102, P:None, Loss:2608.2164, Loss-ae:2608.2161, Loss-topo:0.0003
# Epoch:103, P:None, Loss:2641.4677, Loss-ae:2641.4674, Loss-topo:0.0003
# Epoch:104, P:None, Loss:2616.4519, Loss-ae:2616.4511, Loss-topo:0.0007
# Epoch:105, P:None, Loss:2588.4953, Loss-ae:2588.4943, Loss-topo:0.0010
# Epoch:106, P:None, Loss:2606.6900, Loss-ae:2606.6894, Loss-topo:0.0006
# Epoch:107, P:None, Loss:2585.3452, Loss-ae:2585.3450, Loss-topo:0.0003
# Epoch:108, P:None, Loss:2610.6789, Loss-ae:2610.6782, Loss-topo:0.0008
# Epoch:109, P:None, Loss:2602.1618, Loss-ae:2602.1608, Loss-topo:0.0010
# Epoch:110, P:None, Loss:2605.5718, Loss-ae:2605.5714, Loss-topo:0.0004
# Epoch:111, P:None, Loss:2615.9121, Loss-ae:2615.9117, Loss-topo:0.0004
# Epoch:112, P:None, Loss:2566.1796, Loss-ae:2566.1794, Loss-topo:0.0002
# Epoch:113, P:None, Loss:2648.3151, Loss-ae:2648.3147, Loss-topo:0.0004
# Epoch:114, P:None, Loss:2609.7525, Loss-ae:2609.7518, Loss-topo:0.0007
# Epoch:115, P:None, Loss:2607.2429, Loss-ae:2607.2420, Loss-topo:0.0008
# Epoch:116, P:None, Loss:2611.4596, Loss-ae:2611.4589, Loss-topo:0.0007
# Epoch:117, P:None, Loss:2583.8650, Loss-ae:2583.8644, Loss-topo:0.0006
# Epoch:118, P:None, Loss:2589.8618, Loss-ae:2589.8609, Loss-topo:0.0009
# Epoch:119, P:None, Loss:2578.4753, Loss-ae:2578.4750, Loss-topo:0.0004
# Epoch:120, P:None, Loss:2609.4543, Loss-ae:2609.4538, Loss-topo:0.0005
# Epoch:121, P:None, Loss:2605.2854, Loss-ae:2605.2847, Loss-topo:0.0007
# Epoch:122, P:None, Loss:2595.9555, Loss-ae:2595.9548, Loss-topo:0.0007
# Epoch:123, P:None, Loss:2612.2802, Loss-ae:2612.2793, Loss-topo:0.0009
# Epoch:124, P:None, Loss:2615.1018, Loss-ae:2615.1012, Loss-topo:0.0006
# Epoch:125, P:None, Loss:2614.0418, Loss-ae:2614.0410, Loss-topo:0.0008
# Epoch:126, P:None, Loss:2594.7721, Loss-ae:2594.7716, Loss-topo:0.0006
# Epoch:127, P:None, Loss:2586.5714, Loss-ae:2586.5708, Loss-topo:0.0005
# Epoch:128, P:None, Loss:2585.7174, Loss-ae:2585.7169, Loss-topo:0.0005
# Epoch:129, P:None, Loss:2600.4977, Loss-ae:2600.4974, Loss-topo:0.0003
# Epoch:130, P:None, Loss:2625.9216, Loss-ae:2625.9207, Loss-topo:0.0010
# Epoch:131, P:None, Loss:2612.1627, Loss-ae:2612.1624, Loss-topo:0.0003
# Epoch:132, P:None, Loss:2594.3237, Loss-ae:2594.3234, Loss-topo:0.0003
# Epoch:133, P:None, Loss:2627.3602, Loss-ae:2627.3595, Loss-topo:0.0007
# Epoch:134, P:None, Loss:2643.7990, Loss-ae:2643.7985, Loss-topo:0.0005
# Epoch:135, P:None, Loss:2614.8759, Loss-ae:2614.8754, Loss-topo:0.0005
# Epoch:136, P:None, Loss:2586.0868, Loss-ae:2586.0866, Loss-topo:0.0002
# Epoch:137, P:None, Loss:2594.6304, Loss-ae:2594.6301, Loss-topo:0.0003
# Epoch:138, P:None, Loss:2590.1542, Loss-ae:2590.1538, Loss-topo:0.0003
# Epoch:139, P:None, Loss:2594.1320, Loss-ae:2594.1316, Loss-topo:0.0004
# Epoch:140, P:None, Loss:2609.3923, Loss-ae:2609.3920, Loss-topo:0.0003
# Epoch:141, P:None, Loss:2603.1435, Loss-ae:2603.1431, Loss-topo:0.0004
# Epoch:142, P:None, Loss:2582.9667, Loss-ae:2582.9663, Loss-topo:0.0004
# Epoch:143, P:None, Loss:2589.2868, Loss-ae:2589.2862, Loss-topo:0.0005
# Epoch:144, P:None, Loss:2593.8798, Loss-ae:2593.8794, Loss-topo:0.0005
# Epoch:145, P:None, Loss:2567.6922, Loss-ae:2567.6919, Loss-topo:0.0004
# Epoch:146, P:None, Loss:2557.4355, Loss-ae:2557.4075, Loss-topo:0.0281
# Epoch:147, P:None, Loss:2021.3831, Loss-ae:2002.7090, Loss-topo:18.6741
# Epoch:148, P:None, Loss:1947.8308, Loss-ae:1940.7487, Loss-topo:7.0821
# Epoch:149, P:None, Loss:1908.6397, Loss-ae:1900.1352, Loss-topo:8.5045
# Epoch:150, P:None, Loss:1867.1227, Loss-ae:1860.1253, Loss-topo:6.9973
# Epoch:151, P:None, Loss:1853.7740, Loss-ae:1848.1356, Loss-topo:5.6383
# Epoch:152, P:None, Loss:1839.2001, Loss-ae:1832.9921, Loss-topo:6.2080
# Epoch:153, P:None, Loss:1770.4356, Loss-ae:1762.4275, Loss-topo:8.0081
# Epoch:154, P:None, Loss:1718.1949, Loss-ae:1703.3553, Loss-topo:14.8396
# Epoch:155, P:None, Loss:1620.5821, Loss-ae:1598.0292, Loss-topo:22.5528
# Epoch:156, P:None, Loss:1540.8107, Loss-ae:1512.6865, Loss-topo:28.1242
# Epoch:157, P:None, Loss:1410.2385, Loss-ae:1378.9363, Loss-topo:31.3023
# Epoch:158, P:None, Loss:1218.1071, Loss-ae:1191.1555, Loss-topo:26.9516
# Epoch:159, P:None, Loss:1027.9212, Loss-ae:986.2507, Loss-topo:41.6705
# Epoch:160, P:None, Loss:865.2476, Loss-ae:809.8297, Loss-topo:55.4179
# Epoch:161, P:None, Loss:753.1787, Loss-ae:685.1947, Loss-topo:67.9840
# Epoch:162, P:None, Loss:628.9965, Loss-ae:582.4153, Loss-topo:46.5812
# Epoch:163, P:None, Loss:567.3874, Loss-ae:521.7758, Loss-topo:45.6115
# Epoch:164, P:None, Loss:561.6673, Loss-ae:506.7093, Loss-topo:54.9580
# Epoch:165, P:None, Loss:514.9511, Loss-ae:476.4255, Loss-topo:38.5256
# Epoch:166, P:None, Loss:489.7829, Loss-ae:451.9854, Loss-topo:37.7975
# Epoch:167, P:None, Loss:467.3051, Loss-ae:441.2501, Loss-topo:26.0550
# Epoch:168, P:None, Loss:464.3080, Loss-ae:432.4282, Loss-topo:31.8799
# Epoch:169, P:None, Loss:450.7003, Loss-ae:419.3534, Loss-topo:31.3469
# Epoch:170, P:None, Loss:440.6892, Loss-ae:414.4962, Loss-topo:26.1931
# Epoch:171, P:None, Loss:456.0716, Loss-ae:434.5519, Loss-topo:21.5197
# Epoch:172, P:None, Loss:435.9049, Loss-ae:415.1250, Loss-topo:20.7799
# Epoch:173, P:None, Loss:426.7567, Loss-ae:403.5331, Loss-topo:23.2236
# Epoch:174, P:None, Loss:435.5467, Loss-ae:418.4259, Loss-topo:17.1208
# Epoch:175, P:None, Loss:450.3064, Loss-ae:429.5399, Loss-topo:20.7665
# Epoch:176, P:None, Loss:421.0133, Loss-ae:399.1518, Loss-topo:21.8615
# Epoch:177, P:None, Loss:418.1197, Loss-ae:395.9808, Loss-topo:22.1389
# Epoch:178, P:None, Loss:425.2966, Loss-ae:405.9180, Loss-topo:19.3786
# Epoch:179, P:None, Loss:411.3987, Loss-ae:391.4379, Loss-topo:19.9607
# Epoch:180, P:None, Loss:408.4129, Loss-ae:390.4030, Loss-topo:18.0099
# Epoch:181, P:None, Loss:417.8327, Loss-ae:399.8569, Loss-topo:17.9758
# Epoch:182, P:None, Loss:404.0492, Loss-ae:383.9602, Loss-topo:20.0891
# Epoch:183, P:None, Loss:394.6520, Loss-ae:378.6641, Loss-topo:15.9879
# Epoch:184, P:None, Loss:400.4881, Loss-ae:382.0791, Loss-topo:18.4089
# Epoch:185, P:None, Loss:403.3205, Loss-ae:383.8085, Loss-topo:19.5120
# Epoch:186, P:None, Loss:418.2023, Loss-ae:394.2114, Loss-topo:23.9908
# Epoch:187, P:None, Loss:376.2311, Loss-ae:357.5792, Loss-topo:18.6519
# Epoch:188, P:None, Loss:372.3528, Loss-ae:355.1669, Loss-topo:17.1859
# Epoch:189, P:None, Loss:371.5052, Loss-ae:350.8010, Loss-topo:20.7042
# Epoch:190, P:None, Loss:379.8986, Loss-ae:356.8700, Loss-topo:23.0285
# Epoch:191, P:None, Loss:379.4383, Loss-ae:356.6680, Loss-topo:22.7703
# Epoch:192, P:None, Loss:359.0951, Loss-ae:337.0456, Loss-topo:22.0494
# Epoch:193, P:None, Loss:358.7129, Loss-ae:336.2148, Loss-topo:22.4981
# Epoch:194, P:None, Loss:335.9860, Loss-ae:312.8115, Loss-topo:23.1746
# Epoch:195, P:None, Loss:339.6293, Loss-ae:315.1112, Loss-topo:24.5181
# Epoch:196, P:None, Loss:350.2693, Loss-ae:323.6304, Loss-topo:26.6389
# Epoch:197, P:None, Loss:322.5669, Loss-ae:296.6491, Loss-topo:25.9179
# Epoch:198, P:None, Loss:330.3487, Loss-ae:304.9583, Loss-topo:25.3904
# Epoch:199, P:None, Loss:317.6209, Loss-ae:291.2266, Loss-topo:26.3944
# Epoch:200, P:None, Loss:320.4823, Loss-ae:296.4332, Loss-topo:24.0491
# Epoch:201, P:None, Loss:315.2686, Loss-ae:292.5005, Loss-topo:22.7682
# Epoch:202, P:None, Loss:313.4239, Loss-ae:289.8596, Loss-topo:23.5642
# Epoch:203, P:None, Loss:299.3271, Loss-ae:279.0332, Loss-topo:20.2938
# Epoch:204, P:None, Loss:299.3944, Loss-ae:275.7877, Loss-topo:23.6067
# Epoch:205, P:None, Loss:300.3740, Loss-ae:280.2879, Loss-topo:20.0861
# Epoch:206, P:None, Loss:289.4523, Loss-ae:267.6795, Loss-topo:21.7728
# Epoch:207, P:None, Loss:300.7580, Loss-ae:275.1789, Loss-topo:25.5791
# Epoch:208, P:None, Loss:273.0259, Loss-ae:252.8543, Loss-topo:20.1716
# Epoch:209, P:None, Loss:278.1317, Loss-ae:256.0233, Loss-topo:22.1085
# Epoch:210, P:None, Loss:272.0678, Loss-ae:253.6899, Loss-topo:18.3779
# Epoch:211, P:None, Loss:278.4570, Loss-ae:258.7672, Loss-topo:19.6898
# Epoch:212, P:None, Loss:273.8957, Loss-ae:253.9294, Loss-topo:19.9663
# Epoch:213, P:None, Loss:272.3341, Loss-ae:253.8524, Loss-topo:18.4817
# Epoch:214, P:None, Loss:266.6873, Loss-ae:248.3066, Loss-topo:18.3807
# Epoch:215, P:None, Loss:276.9949, Loss-ae:257.3899, Loss-topo:19.6050
# Epoch:216, P:None, Loss:268.1920, Loss-ae:251.0814, Loss-topo:17.1106
# Epoch:217, P:None, Loss:261.9686, Loss-ae:246.0594, Loss-topo:15.9092
# Epoch:218, P:None, Loss:257.9320, Loss-ae:240.9844, Loss-topo:16.9475
# Epoch:219, P:None, Loss:252.1092, Loss-ae:237.0756, Loss-topo:15.0335
# Epoch:220, P:None, Loss:260.1123, Loss-ae:244.0537, Loss-topo:16.0586
# Epoch:221, P:None, Loss:251.8311, Loss-ae:237.2108, Loss-topo:14.6203
# Epoch:222, P:None, Loss:251.9910, Loss-ae:236.4518, Loss-topo:15.5392
# Epoch:223, P:None, Loss:251.4946, Loss-ae:237.1286, Loss-topo:14.3660
# Epoch:224, P:None, Loss:248.4358, Loss-ae:233.0677, Loss-topo:15.3681
# Epoch:225, P:None, Loss:246.8134, Loss-ae:232.8929, Loss-topo:13.9205
# Epoch:226, P:None, Loss:238.9456, Loss-ae:225.8347, Loss-topo:13.1110
# Epoch:227, P:None, Loss:257.5288, Loss-ae:243.1715, Loss-topo:14.3573
# Epoch:228, P:None, Loss:241.1707, Loss-ae:228.4319, Loss-topo:12.7389
# Epoch:229, P:None, Loss:240.1330, Loss-ae:228.2111, Loss-topo:11.9219
# Epoch:230, P:None, Loss:235.4788, Loss-ae:223.1506, Loss-topo:12.3281
# Epoch:231, P:None, Loss:241.7574, Loss-ae:228.8964, Loss-topo:12.8610
# Epoch:232, P:None, Loss:246.3458, Loss-ae:233.2027, Loss-topo:13.1431
# Epoch:233, P:None, Loss:232.5848, Loss-ae:220.5617, Loss-topo:12.0231
# Epoch:234, P:None, Loss:238.4318, Loss-ae:227.2968, Loss-topo:11.1350
# Epoch:235, P:None, Loss:237.6054, Loss-ae:225.8450, Loss-topo:11.7604
# Epoch:236, P:None, Loss:225.2515, Loss-ae:216.3778, Loss-topo:8.8736
# Epoch:237, P:None, Loss:233.6577, Loss-ae:223.7445, Loss-topo:9.9132
# Epoch:238, P:None, Loss:233.5841, Loss-ae:223.0455, Loss-topo:10.5385
# Epoch:239, P:None, Loss:235.4599, Loss-ae:225.5523, Loss-topo:9.9076
# Epoch:240, P:None, Loss:238.8666, Loss-ae:229.0456, Loss-topo:9.8211
# Epoch:241, P:None, Loss:238.8814, Loss-ae:228.6877, Loss-topo:10.1936
# Epoch:242, P:None, Loss:231.6222, Loss-ae:221.6979, Loss-topo:9.9243
# Epoch:243, P:None, Loss:232.2058, Loss-ae:222.4619, Loss-topo:9.7439
# Epoch:244, P:None, Loss:225.2652, Loss-ae:215.9380, Loss-topo:9.3272
# Epoch:245, P:None, Loss:223.7210, Loss-ae:214.4593, Loss-topo:9.2617
# Epoch:246, P:None, Loss:225.6473, Loss-ae:216.7589, Loss-topo:8.8884
# Epoch:247, P:None, Loss:233.0696, Loss-ae:224.2539, Loss-topo:8.8157
# Epoch:248, P:None, Loss:230.8394, Loss-ae:222.1074, Loss-topo:8.7320
# Epoch:249, P:None, Loss:220.2459, Loss-ae:211.6870, Loss-topo:8.5589
# Epoch:250, P:None, Loss:226.6314, Loss-ae:218.6863, Loss-topo:7.9451
# Epoch:251, P:None, Loss:223.7534, Loss-ae:214.9292, Loss-topo:8.8242
# Epoch:252, P:None, Loss:224.2013, Loss-ae:216.2694, Loss-topo:7.9319
# Epoch:253, P:None, Loss:214.8988, Loss-ae:206.5888, Loss-topo:8.3099
# Epoch:254, P:None, Loss:224.9839, Loss-ae:216.1963, Loss-topo:8.7876
# Epoch:255, P:None, Loss:222.1207, Loss-ae:214.2076, Loss-topo:7.9131
# Epoch:256, P:None, Loss:227.8013, Loss-ae:218.9435, Loss-topo:8.8578
# Epoch:257, P:None, Loss:222.4578, Loss-ae:214.8553, Loss-topo:7.6025
# Epoch:258, P:None, Loss:224.8280, Loss-ae:217.2554, Loss-topo:7.5726
# Epoch:259, P:None, Loss:213.9976, Loss-ae:206.6498, Loss-topo:7.3478
# Epoch:260, P:None, Loss:216.8847, Loss-ae:209.3304, Loss-topo:7.5543
# Epoch:261, P:None, Loss:218.3749, Loss-ae:210.7706, Loss-topo:7.6043
# Epoch:262, P:None, Loss:219.5867, Loss-ae:212.4418, Loss-topo:7.1450
# Epoch:263, P:None, Loss:218.6865, Loss-ae:210.7243, Loss-topo:7.9622
# Epoch:264, P:None, Loss:215.2485, Loss-ae:207.8746, Loss-topo:7.3739
# Epoch:265, P:None, Loss:211.1902, Loss-ae:204.1459, Loss-topo:7.0442
# Epoch:266, P:None, Loss:212.6266, Loss-ae:205.4107, Loss-topo:7.2159
# Epoch:267, P:None, Loss:214.1357, Loss-ae:206.8052, Loss-topo:7.3306
# Epoch:268, P:None, Loss:212.0398, Loss-ae:205.2807, Loss-topo:6.7591
# Epoch:269, P:None, Loss:210.2643, Loss-ae:203.5079, Loss-topo:6.7564
# Epoch:270, P:None, Loss:211.8926, Loss-ae:204.8803, Loss-topo:7.0124
# Epoch:271, P:None, Loss:214.2824, Loss-ae:207.0940, Loss-topo:7.1884
# Epoch:272, P:None, Loss:202.9252, Loss-ae:196.2147, Loss-topo:6.7105
# Epoch:273, P:None, Loss:206.5211, Loss-ae:199.7544, Loss-topo:6.7667
# Epoch:274, P:None, Loss:211.8936, Loss-ae:204.8957, Loss-topo:6.9979
# Epoch:275, P:None, Loss:222.1215, Loss-ae:214.1296, Loss-topo:7.9918
# Epoch:276, P:None, Loss:200.8248, Loss-ae:194.3414, Loss-topo:6.4834
# Epoch:277, P:None, Loss:213.9954, Loss-ae:207.0492, Loss-topo:6.9463
# Epoch:278, P:None, Loss:201.2878, Loss-ae:194.8189, Loss-topo:6.4689
# Epoch:279, P:None, Loss:204.3669, Loss-ae:197.5729, Loss-topo:6.7940
# Epoch:280, P:None, Loss:207.2107, Loss-ae:200.1007, Loss-topo:7.1100
# Epoch:281, P:None, Loss:199.8576, Loss-ae:193.9278, Loss-topo:5.9298
# Epoch:282, P:None, Loss:201.5458, Loss-ae:195.4966, Loss-topo:6.0492
# Epoch:283, P:None, Loss:197.1144, Loss-ae:190.9749, Loss-topo:6.1395
# Epoch:284, P:None, Loss:207.4001, Loss-ae:201.0805, Loss-topo:6.3195
# Epoch:285, P:None, Loss:205.8861, Loss-ae:199.5695, Loss-topo:6.3166
# Epoch:286, P:None, Loss:204.2000, Loss-ae:198.2095, Loss-topo:5.9905
# Epoch:287, P:None, Loss:193.9138, Loss-ae:187.8784, Loss-topo:6.0355
# Epoch:288, P:None, Loss:197.2162, Loss-ae:191.1836, Loss-topo:6.0326
# Epoch:289, P:None, Loss:200.0980, Loss-ae:194.0519, Loss-topo:6.0461
# Epoch:290, P:None, Loss:193.2579, Loss-ae:187.5400, Loss-topo:5.7179
# Epoch:291, P:None, Loss:205.8893, Loss-ae:199.6762, Loss-topo:6.2131
# Epoch:292, P:None, Loss:199.0039, Loss-ae:193.0570, Loss-topo:5.9470
# Epoch:293, P:None, Loss:190.9326, Loss-ae:185.3236, Loss-topo:5.6090
# Epoch:294, P:None, Loss:191.8453, Loss-ae:186.6209, Loss-topo:5.2244
# Epoch:295, P:None, Loss:198.3477, Loss-ae:192.3834, Loss-topo:5.9643
# Epoch:296, P:None, Loss:197.5232, Loss-ae:192.1540, Loss-topo:5.3692
# Epoch:297, P:None, Loss:199.1867, Loss-ae:194.0296, Loss-topo:5.1571
# Epoch:298, P:None, Loss:192.7872, Loss-ae:187.1622, Loss-topo:5.6250
# Epoch:299, P:None, Loss:200.5742, Loss-ae:194.9440, Loss-topo:5.6302
# Epoch:300, P:None, Loss:202.1469, Loss-ae:196.5557, Loss-topo:5.5911
# Epoch:301, P:None, Loss:200.4547, Loss-ae:195.2120, Loss-topo:5.2427
# Epoch:302, P:None, Loss:193.4651, Loss-ae:188.0557, Loss-topo:5.4093
# Epoch:303, P:None, Loss:198.1493, Loss-ae:192.6329, Loss-topo:5.5164
# Epoch:304, P:None, Loss:199.7028, Loss-ae:194.5264, Loss-topo:5.1764
# Epoch:305, P:None, Loss:192.6390, Loss-ae:187.7659, Loss-topo:4.8732
# Epoch:306, P:None, Loss:190.1573, Loss-ae:185.6795, Loss-topo:4.4778
# Epoch:307, P:None, Loss:193.3364, Loss-ae:188.6419, Loss-topo:4.6945
# Epoch:308, P:None, Loss:190.7757, Loss-ae:185.8626, Loss-topo:4.9132
# Epoch:309, P:None, Loss:196.0402, Loss-ae:191.2480, Loss-topo:4.7921
# Epoch:310, P:None, Loss:195.9272, Loss-ae:191.0732, Loss-topo:4.8540
# Epoch:311, P:None, Loss:188.3889, Loss-ae:184.3182, Loss-topo:4.0707
# Epoch:312, P:None, Loss:199.2346, Loss-ae:194.8353, Loss-topo:4.3994
# Epoch:313, P:None, Loss:191.6168, Loss-ae:187.3825, Loss-topo:4.2343
# Epoch:314, P:None, Loss:188.9238, Loss-ae:184.7385, Loss-topo:4.1854
# Epoch:315, P:None, Loss:197.3664, Loss-ae:193.2387, Loss-topo:4.1277
# Epoch:316, P:None, Loss:196.9556, Loss-ae:192.6965, Loss-topo:4.2591
# Epoch:317, P:None, Loss:186.0949, Loss-ae:181.9569, Loss-topo:4.1381
# Epoch:318, P:None, Loss:191.7966, Loss-ae:187.7394, Loss-topo:4.0572
# Epoch:319, P:None, Loss:183.3094, Loss-ae:179.3992, Loss-topo:3.9102
# Epoch:320, P:None, Loss:193.0490, Loss-ae:188.8014, Loss-topo:4.2476
# Epoch:321, P:None, Loss:184.2098, Loss-ae:180.7041, Loss-topo:3.5058
# Epoch:322, P:None, Loss:192.4795, Loss-ae:188.2597, Loss-topo:4.2199
# Epoch:323, P:None, Loss:187.6550, Loss-ae:184.2934, Loss-topo:3.3617
# Epoch:324, P:None, Loss:189.4475, Loss-ae:185.8381, Loss-topo:3.6094
# Epoch:325, P:None, Loss:191.6505, Loss-ae:187.7749, Loss-topo:3.8756
# Epoch:326, P:None, Loss:187.9033, Loss-ae:184.2187, Loss-topo:3.6846
# Epoch:327, P:None, Loss:186.7170, Loss-ae:183.1841, Loss-topo:3.5329
# Epoch:328, P:None, Loss:193.2726, Loss-ae:189.5986, Loss-topo:3.6740
# Epoch:329, P:None, Loss:187.5230, Loss-ae:183.7822, Loss-topo:3.7408
# Epoch:330, P:None, Loss:188.0197, Loss-ae:184.6484, Loss-topo:3.3713
# Epoch:331, P:None, Loss:190.4459, Loss-ae:187.0849, Loss-topo:3.3610
# Epoch:332, P:None, Loss:183.5955, Loss-ae:180.2560, Loss-topo:3.3395
# Epoch:333, P:None, Loss:187.9953, Loss-ae:184.7923, Loss-topo:3.2030
# Epoch:334, P:None, Loss:185.2376, Loss-ae:181.6489, Loss-topo:3.5887
# Epoch:335, P:None, Loss:185.7078, Loss-ae:182.4947, Loss-topo:3.2131
# Epoch:336, P:None, Loss:190.4068, Loss-ae:187.2563, Loss-topo:3.1505
# Epoch:337, P:None, Loss:191.0947, Loss-ae:187.6359, Loss-topo:3.4589
# Epoch:338, P:None, Loss:186.5386, Loss-ae:183.6614, Loss-topo:2.8772
# Epoch:339, P:None, Loss:194.2815, Loss-ae:191.0504, Loss-topo:3.2311
# Epoch:340, P:None, Loss:183.6803, Loss-ae:180.5391, Loss-topo:3.1411
# Epoch:341, P:None, Loss:184.9999, Loss-ae:181.7581, Loss-topo:3.2418
# Epoch:342, P:None, Loss:177.9145, Loss-ae:175.0104, Loss-topo:2.9041
# Epoch:343, P:None, Loss:186.9258, Loss-ae:183.9806, Loss-topo:2.9452
# Epoch:344, P:None, Loss:183.2279, Loss-ae:180.5093, Loss-topo:2.7186
# Epoch:345, P:None, Loss:183.4438, Loss-ae:180.4201, Loss-topo:3.0237
# Epoch:346, P:None, Loss:184.0355, Loss-ae:180.9495, Loss-topo:3.0860
# Epoch:347, P:None, Loss:182.2463, Loss-ae:179.0146, Loss-topo:3.2318
# Epoch:348, P:None, Loss:176.8707, Loss-ae:174.2192, Loss-topo:2.6515
# Epoch:349, P:None, Loss:182.9459, Loss-ae:180.0845, Loss-topo:2.8614
# Epoch:350, P:None, Loss:175.9761, Loss-ae:173.4695, Loss-topo:2.5066
# Epoch:351, P:None, Loss:182.5190, Loss-ae:179.8924, Loss-topo:2.6266
# Epoch:352, P:None, Loss:174.3957, Loss-ae:172.0706, Loss-topo:2.3251
# Epoch:353, P:None, Loss:173.7497, Loss-ae:171.2612, Loss-topo:2.4885
# Epoch:354, P:None, Loss:176.6706, Loss-ae:174.1432, Loss-topo:2.5274
# Epoch:355, P:None, Loss:182.2385, Loss-ae:179.6534, Loss-topo:2.5851
# Epoch:356, P:None, Loss:183.6799, Loss-ae:181.0942, Loss-topo:2.5857
# Epoch:357, P:None, Loss:177.3396, Loss-ae:174.9535, Loss-topo:2.3861
# Epoch:358, P:None, Loss:176.2787, Loss-ae:173.5760, Loss-topo:2.7027
# Epoch:359, P:None, Loss:177.5254, Loss-ae:175.2085, Loss-topo:2.3168
# Epoch:360, P:None, Loss:184.3580, Loss-ae:181.5976, Loss-topo:2.7604
# Epoch:361, P:None, Loss:189.5241, Loss-ae:187.0602, Loss-topo:2.4639
# Epoch:362, P:None, Loss:184.5499, Loss-ae:182.1501, Loss-topo:2.3998
# Epoch:363, P:None, Loss:186.0629, Loss-ae:183.6282, Loss-topo:2.4347
# Epoch:364, P:None, Loss:179.2082, Loss-ae:176.6458, Loss-topo:2.5624
# Epoch:365, P:None, Loss:173.7088, Loss-ae:171.4712, Loss-topo:2.2376
# Epoch:366, P:None, Loss:179.8727, Loss-ae:177.3803, Loss-topo:2.4924
# Epoch:367, P:None, Loss:176.3856, Loss-ae:174.3407, Loss-topo:2.0449
# Epoch:368, P:None, Loss:178.5856, Loss-ae:176.2876, Loss-topo:2.2980
# Epoch:369, P:None, Loss:175.4578, Loss-ae:173.1466, Loss-topo:2.3112
# Epoch:370, P:None, Loss:181.1803, Loss-ae:178.9026, Loss-topo:2.2776
# Epoch:371, P:None, Loss:171.5044, Loss-ae:169.4291, Loss-topo:2.0754
# Epoch:372, P:None, Loss:181.4671, Loss-ae:179.1505, Loss-topo:2.3167
# Epoch:373, P:None, Loss:178.7521, Loss-ae:176.6408, Loss-topo:2.1113
# Epoch:374, P:None, Loss:173.3453, Loss-ae:171.2229, Loss-topo:2.1225
# Epoch:375, P:None, Loss:170.5631, Loss-ae:168.4764, Loss-topo:2.0868
# Epoch:376, P:None, Loss:178.8700, Loss-ae:176.7344, Loss-topo:2.1356
# Epoch:377, P:None, Loss:173.7565, Loss-ae:171.6421, Loss-topo:2.1144
# Epoch:378, P:None, Loss:179.8176, Loss-ae:177.5684, Loss-topo:2.2492
# Epoch:379, P:None, Loss:174.5702, Loss-ae:172.4902, Loss-topo:2.0801
# Epoch:380, P:None, Loss:180.2841, Loss-ae:177.8824, Loss-topo:2.4017
# Epoch:381, P:None, Loss:172.7790, Loss-ae:170.9514, Loss-topo:1.8277
# Epoch:382, P:None, Loss:172.8332, Loss-ae:170.9828, Loss-topo:1.8504
# Epoch:383, P:None, Loss:173.3661, Loss-ae:171.3475, Loss-topo:2.0186
# Epoch:384, P:None, Loss:168.0333, Loss-ae:166.1896, Loss-topo:1.8438
# Epoch:385, P:None, Loss:170.8337, Loss-ae:168.9134, Loss-topo:1.9203
# Epoch:386, P:None, Loss:176.7619, Loss-ae:174.7573, Loss-topo:2.0046
# Epoch:387, P:None, Loss:171.3012, Loss-ae:169.5244, Loss-topo:1.7767
# Epoch:388, P:None, Loss:170.8608, Loss-ae:168.9699, Loss-topo:1.8909
# Epoch:389, P:None, Loss:172.0649, Loss-ae:170.3958, Loss-topo:1.6691
# Epoch:390, P:None, Loss:174.8972, Loss-ae:173.0218, Loss-topo:1.8754
# Epoch:391, P:None, Loss:169.3644, Loss-ae:167.5871, Loss-topo:1.7773
# Epoch:392, P:None, Loss:168.5449, Loss-ae:166.7974, Loss-topo:1.7474
# Epoch:393, P:None, Loss:171.9455, Loss-ae:170.2191, Loss-topo:1.7264
# Epoch:394, P:None, Loss:174.9590, Loss-ae:172.9507, Loss-topo:2.0082
# Epoch:395, P:None, Loss:165.2550, Loss-ae:163.5968, Loss-topo:1.6582
# Epoch:396, P:None, Loss:167.6691, Loss-ae:165.9801, Loss-topo:1.6890
# Epoch:397, P:None, Loss:162.8762, Loss-ae:161.1278, Loss-topo:1.7483
# Epoch:398, P:None, Loss:172.7096, Loss-ae:170.9628, Loss-topo:1.7468
# Epoch:399, P:None, Loss:162.7570, Loss-ae:161.1588, Loss-topo:1.5982
# Epoch:400, P:None, Loss:167.1743, Loss-ae:165.5831, Loss-topo:1.5912
# Epoch:401, P:None, Loss:168.0749, Loss-ae:166.4712, Loss-topo:1.6037
# Epoch:402, P:None, Loss:172.7110, Loss-ae:171.0094, Loss-topo:1.7015
# Epoch:403, P:None, Loss:165.5451, Loss-ae:163.9506, Loss-topo:1.5945
# Epoch:404, P:None, Loss:164.8671, Loss-ae:163.3512, Loss-topo:1.5158
# Epoch:405, P:None, Loss:168.0795, Loss-ae:166.5194, Loss-topo:1.5601
# Epoch:406, P:None, Loss:164.0465, Loss-ae:162.3793, Loss-topo:1.6672
# Epoch:407, P:None, Loss:169.6011, Loss-ae:168.0304, Loss-topo:1.5707
# Epoch:408, P:None, Loss:170.4479, Loss-ae:168.9248, Loss-topo:1.5231
# Epoch:409, P:None, Loss:165.7664, Loss-ae:164.2166, Loss-topo:1.5498
# Epoch:410, P:None, Loss:166.9581, Loss-ae:165.4434, Loss-topo:1.5147
# Epoch:411, P:None, Loss:166.7856, Loss-ae:165.1901, Loss-topo:1.5955
# Epoch:412, P:None, Loss:163.8629, Loss-ae:162.4428, Loss-topo:1.4202
# Epoch:413, P:None, Loss:167.3286, Loss-ae:165.7543, Loss-topo:1.5744
# Epoch:414, P:None, Loss:165.9236, Loss-ae:164.4931, Loss-topo:1.4305
# Epoch:415, P:None, Loss:166.6650, Loss-ae:165.1797, Loss-topo:1.4853
# Epoch:416, P:None, Loss:166.4696, Loss-ae:165.0016, Loss-topo:1.4680
# Epoch:417, P:None, Loss:169.5480, Loss-ae:168.1217, Loss-topo:1.4263
# Epoch:418, P:None, Loss:168.2759, Loss-ae:166.8772, Loss-topo:1.3987
# Epoch:419, P:None, Loss:169.7792, Loss-ae:168.3135, Loss-topo:1.4657
# Epoch:420, P:None, Loss:166.3789, Loss-ae:164.9061, Loss-topo:1.4728
# Epoch:421, P:None, Loss:163.2025, Loss-ae:161.8209, Loss-topo:1.3816
# Epoch:422, P:None, Loss:163.9012, Loss-ae:162.5441, Loss-topo:1.3572
# Epoch:423, P:None, Loss:165.6343, Loss-ae:164.2938, Loss-topo:1.3405
# Epoch:424, P:None, Loss:163.5741, Loss-ae:162.1490, Loss-topo:1.4251
# Epoch:425, P:None, Loss:168.2842, Loss-ae:166.9441, Loss-topo:1.3401
# Epoch:426, P:None, Loss:162.4372, Loss-ae:161.1943, Loss-topo:1.2429
# Epoch:427, P:None, Loss:167.1161, Loss-ae:165.8676, Loss-topo:1.2485
# Epoch:428, P:None, Loss:162.9672, Loss-ae:161.7353, Loss-topo:1.2319
# Epoch:429, P:None, Loss:165.2969, Loss-ae:164.0485, Loss-topo:1.2484
# Epoch:430, P:None, Loss:164.0558, Loss-ae:162.9030, Loss-topo:1.1528
# Epoch:431, P:None, Loss:163.0164, Loss-ae:161.7822, Loss-topo:1.2342
# Epoch:432, P:None, Loss:164.5013, Loss-ae:163.3357, Loss-topo:1.1656
# Epoch:433, P:None, Loss:169.4516, Loss-ae:168.2675, Loss-topo:1.1841
# Epoch:434, P:None, Loss:160.6158, Loss-ae:159.4072, Loss-topo:1.2086
# Epoch:435, P:None, Loss:161.6938, Loss-ae:160.5713, Loss-topo:1.1225
# Epoch:436, P:None, Loss:163.4663, Loss-ae:162.2231, Loss-topo:1.2431
# Epoch:437, P:None, Loss:164.2085, Loss-ae:163.0749, Loss-topo:1.1337
# Epoch:438, P:None, Loss:159.4710, Loss-ae:158.3561, Loss-topo:1.1149
# Epoch:439, P:None, Loss:161.7210, Loss-ae:160.5970, Loss-topo:1.1240
# Epoch:440, P:None, Loss:170.1073, Loss-ae:168.8336, Loss-topo:1.2737
# Epoch:441, P:None, Loss:168.8205, Loss-ae:167.6172, Loss-topo:1.2033
# Epoch:442, P:None, Loss:162.9245, Loss-ae:161.8392, Loss-topo:1.0853
# Epoch:443, P:None, Loss:158.7227, Loss-ae:157.7812, Loss-topo:0.9414
# Epoch:444, P:None, Loss:165.7357, Loss-ae:164.7034, Loss-topo:1.0324
# Epoch:445, P:None, Loss:164.1294, Loss-ae:163.0308, Loss-topo:1.0986
# Epoch:446, P:None, Loss:158.7753, Loss-ae:157.7102, Loss-topo:1.0651
# Epoch:447, P:None, Loss:170.6126, Loss-ae:169.5142, Loss-topo:1.0984
# Epoch:448, P:None, Loss:164.6766, Loss-ae:163.6536, Loss-topo:1.0230
# Epoch:449, P:None, Loss:163.4879, Loss-ae:162.3780, Loss-topo:1.1099
# Epoch:450, P:None, Loss:160.0208, Loss-ae:159.0751, Loss-topo:0.9457
# Epoch:451, P:None, Loss:165.4939, Loss-ae:164.3156, Loss-topo:1.1782
# Epoch:452, P:None, Loss:167.6980, Loss-ae:166.5649, Loss-topo:1.1331
# Epoch:453, P:None, Loss:157.6153, Loss-ae:156.6327, Loss-topo:0.9827
# Epoch:454, P:None, Loss:163.2211, Loss-ae:162.1496, Loss-topo:1.0716
# Epoch:455, P:None, Loss:160.4330, Loss-ae:159.3795, Loss-topo:1.0535
# Epoch:456, P:None, Loss:162.5988, Loss-ae:161.6099, Loss-topo:0.9889
# Epoch:457, P:None, Loss:158.4508, Loss-ae:157.5014, Loss-topo:0.9494
# Epoch:458, P:None, Loss:161.4447, Loss-ae:160.4678, Loss-topo:0.9769
# Epoch:459, P:None, Loss:163.6887, Loss-ae:162.6728, Loss-topo:1.0159
# Epoch:460, P:None, Loss:159.3442, Loss-ae:158.4257, Loss-topo:0.9185
# Epoch:461, P:None, Loss:164.2101, Loss-ae:163.2080, Loss-topo:1.0021
# Epoch:462, P:None, Loss:166.1593, Loss-ae:165.1179, Loss-topo:1.0414
# Epoch:463, P:None, Loss:157.9018, Loss-ae:157.0662, Loss-topo:0.8356
# Epoch:464, P:None, Loss:158.1232, Loss-ae:157.1891, Loss-topo:0.9341
# Epoch:465, P:None, Loss:157.2821, Loss-ae:156.3822, Loss-topo:0.9000
# Epoch:466, P:None, Loss:159.5404, Loss-ae:158.6510, Loss-topo:0.8894
# Epoch:467, P:None, Loss:158.4678, Loss-ae:157.6164, Loss-topo:0.8514
# Epoch:468, P:None, Loss:161.5080, Loss-ae:160.6034, Loss-topo:0.9046
# Epoch:469, P:None, Loss:163.1910, Loss-ae:162.2526, Loss-topo:0.9385
# Epoch:470, P:None, Loss:157.7538, Loss-ae:156.9036, Loss-topo:0.8503
# Epoch:471, P:None, Loss:158.9717, Loss-ae:158.0026, Loss-topo:0.9690
# Epoch:472, P:None, Loss:158.9470, Loss-ae:158.0616, Loss-topo:0.8854
# Epoch:473, P:None, Loss:158.1571, Loss-ae:157.2623, Loss-topo:0.8948
# Epoch:474, P:None, Loss:155.1645, Loss-ae:154.3376, Loss-topo:0.8270
# Epoch:475, P:None, Loss:154.1562, Loss-ae:153.2852, Loss-topo:0.8710
# Epoch:476, P:None, Loss:162.2800, Loss-ae:161.4114, Loss-topo:0.8685
# Epoch:477, P:None, Loss:159.3365, Loss-ae:158.3896, Loss-topo:0.9469
# Epoch:478, P:None, Loss:159.6888, Loss-ae:158.8166, Loss-topo:0.8722
# Epoch:479, P:None, Loss:160.2294, Loss-ae:159.2897, Loss-topo:0.9397
# Epoch:480, P:None, Loss:157.4590, Loss-ae:156.6127, Loss-topo:0.8463
# Epoch:481, P:None, Loss:163.7389, Loss-ae:162.7773, Loss-topo:0.9616
# Epoch:482, P:None, Loss:160.0526, Loss-ae:159.1932, Loss-topo:0.8594
# Epoch:483, P:None, Loss:166.2749, Loss-ae:165.4194, Loss-topo:0.8555
# Epoch:484, P:None, Loss:153.7117, Loss-ae:152.9805, Loss-topo:0.7312
# Epoch:485, P:None, Loss:161.9665, Loss-ae:161.0966, Loss-topo:0.8698
# Epoch:486, P:None, Loss:151.7063, Loss-ae:150.9662, Loss-topo:0.7401
# Epoch:487, P:None, Loss:166.9583, Loss-ae:166.1314, Loss-topo:0.8270
# Epoch:488, P:None, Loss:160.3693, Loss-ae:159.5573, Loss-topo:0.8121
# Epoch:489, P:None, Loss:158.9426, Loss-ae:158.1492, Loss-topo:0.7935
# Epoch:490, P:None, Loss:160.3877, Loss-ae:159.5237, Loss-topo:0.8641
# Epoch:491, P:None, Loss:161.2364, Loss-ae:160.4426, Loss-topo:0.7939
# Epoch:492, P:None, Loss:156.4548, Loss-ae:155.7234, Loss-topo:0.7314
# Epoch:493, P:None, Loss:160.8369, Loss-ae:160.0762, Loss-topo:0.7607
# Epoch:494, P:None, Loss:165.4701, Loss-ae:164.6615, Loss-topo:0.8086
# Epoch:495, P:None, Loss:158.1387, Loss-ae:157.4020, Loss-topo:0.7367
# Epoch:496, P:None, Loss:153.9584, Loss-ae:153.2181, Loss-topo:0.7403
# Epoch:497, P:None, Loss:158.8835, Loss-ae:158.0631, Loss-topo:0.8204
# Epoch:498, P:None, Loss:159.1097, Loss-ae:158.3386, Loss-topo:0.7711
# Epoch:499, P:None, Loss:157.3489, Loss-ae:156.6310, Loss-topo:0.7179
# Epoch:500, P:None, Loss:158.5927, Loss-ae:157.8275, Loss-topo:0.7652
# Epoch:501, P:None, Loss:164.1296, Loss-ae:163.3084, Loss-topo:0.8212
# Epoch:502, P:None, Loss:156.0404, Loss-ae:155.3170, Loss-topo:0.7234
# Epoch:503, P:None, Loss:162.3159, Loss-ae:161.5344, Loss-topo:0.7816
# Epoch:504, P:None, Loss:153.2190, Loss-ae:152.5344, Loss-topo:0.6845
# Epoch:505, P:None, Loss:158.2451, Loss-ae:157.4939, Loss-topo:0.7512
# Epoch:506, P:None, Loss:153.8900, Loss-ae:153.1721, Loss-topo:0.7178
# Epoch:507, P:None, Loss:159.4580, Loss-ae:158.7425, Loss-topo:0.7155
# Epoch:508, P:None, Loss:153.5067, Loss-ae:152.7864, Loss-topo:0.7203
# Epoch:509, P:None, Loss:156.5713, Loss-ae:155.8902, Loss-topo:0.6811
# Epoch:510, P:None, Loss:157.8656, Loss-ae:157.1453, Loss-topo:0.7202
# Epoch:511, P:None, Loss:157.0872, Loss-ae:156.3907, Loss-topo:0.6965
# Epoch:512, P:None, Loss:152.7711, Loss-ae:152.1104, Loss-topo:0.6607
# Epoch:513, P:None, Loss:164.4548, Loss-ae:163.6834, Loss-topo:0.7714
# Epoch:514, P:None, Loss:161.1391, Loss-ae:160.4320, Loss-topo:0.7070
# Epoch:515, P:None, Loss:155.1634, Loss-ae:154.4919, Loss-topo:0.6715
# Epoch:516, P:None, Loss:157.3798, Loss-ae:156.7273, Loss-topo:0.6525
# Epoch:517, P:None, Loss:159.0255, Loss-ae:158.3527, Loss-topo:0.6728
# Epoch:518, P:None, Loss:156.0261, Loss-ae:155.3829, Loss-topo:0.6431
# Epoch:519, P:None, Loss:160.1017, Loss-ae:159.4165, Loss-topo:0.6851
# Epoch:520, P:None, Loss:156.1806, Loss-ae:155.5418, Loss-topo:0.6388
# Epoch:521, P:None, Loss:152.4580, Loss-ae:151.8549, Loss-topo:0.6032
# Epoch:522, P:None, Loss:157.8686, Loss-ae:157.1912, Loss-topo:0.6774
# Epoch:523, P:None, Loss:155.8800, Loss-ae:155.2564, Loss-topo:0.6236
# Epoch:524, P:None, Loss:164.8474, Loss-ae:164.1391, Loss-topo:0.7083
# Epoch:525, P:None, Loss:150.9010, Loss-ae:150.2877, Loss-topo:0.6132
# Epoch:526, P:None, Loss:165.4976, Loss-ae:164.7332, Loss-topo:0.7643
# Epoch:527, P:None, Loss:155.1579, Loss-ae:154.4896, Loss-topo:0.6683
# Epoch:528, P:None, Loss:158.3929, Loss-ae:157.6982, Loss-topo:0.6947
# Epoch:529, P:None, Loss:161.7217, Loss-ae:161.0760, Loss-topo:0.6457
# Epoch:530, P:None, Loss:157.0521, Loss-ae:156.3939, Loss-topo:0.6582
# Epoch:531, P:None, Loss:154.9735, Loss-ae:154.3642, Loss-topo:0.6094
# Epoch:532, P:None, Loss:160.8236, Loss-ae:160.1545, Loss-topo:0.6691
# Epoch:533, P:None, Loss:157.7211, Loss-ae:157.0809, Loss-topo:0.6402
# Epoch:534, P:None, Loss:152.3207, Loss-ae:151.7392, Loss-topo:0.5815
# Epoch:535, P:None, Loss:154.9109, Loss-ae:154.3404, Loss-topo:0.5705
# Epoch:536, P:None, Loss:158.2092, Loss-ae:157.6362, Loss-topo:0.5730
# Epoch:537, P:None, Loss:158.6873, Loss-ae:158.0830, Loss-topo:0.6044
# Epoch:538, P:None, Loss:150.5732, Loss-ae:150.0337, Loss-topo:0.5395
# Epoch:539, P:None, Loss:154.7190, Loss-ae:154.1606, Loss-topo:0.5584
# Epoch:540, P:None, Loss:158.6067, Loss-ae:158.0338, Loss-topo:0.5730
# Epoch:541, P:None, Loss:156.5058, Loss-ae:155.9101, Loss-topo:0.5957
# Epoch:542, P:None, Loss:155.9105, Loss-ae:155.3482, Loss-topo:0.5624
# Epoch:543, P:None, Loss:155.5224, Loss-ae:154.9284, Loss-topo:0.5940
# Epoch:544, P:None, Loss:156.6551, Loss-ae:156.0701, Loss-topo:0.5850
# Epoch:545, P:None, Loss:157.9592, Loss-ae:157.3301, Loss-topo:0.6292
# Epoch:546, P:None, Loss:157.7233, Loss-ae:157.1673, Loss-topo:0.5560
# Epoch:547, P:None, Loss:156.0874, Loss-ae:155.4998, Loss-topo:0.5876
# Epoch:548, P:None, Loss:158.5586, Loss-ae:157.9640, Loss-topo:0.5947
# Epoch:549, P:None, Loss:152.4212, Loss-ae:151.8606, Loss-topo:0.5606
# Epoch:550, P:None, Loss:155.3017, Loss-ae:154.7584, Loss-topo:0.5432
# Epoch:551, P:None, Loss:164.6058, Loss-ae:163.9995, Loss-topo:0.6062
# Epoch:552, P:None, Loss:155.6586, Loss-ae:155.1292, Loss-topo:0.5294
# Epoch:553, P:None, Loss:161.7794, Loss-ae:161.1865, Loss-topo:0.5929
# Epoch:554, P:None, Loss:163.0055, Loss-ae:162.4570, Loss-topo:0.5485
# Epoch:555, P:None, Loss:153.3687, Loss-ae:152.8648, Loss-topo:0.5039
# Epoch:556, P:None, Loss:154.7778, Loss-ae:154.2434, Loss-topo:0.5344
# Epoch:557, P:None, Loss:149.6096, Loss-ae:149.1379, Loss-topo:0.4718
# Epoch:558, P:None, Loss:155.4898, Loss-ae:154.9612, Loss-topo:0.5286
# Epoch:559, P:None, Loss:153.9554, Loss-ae:153.4432, Loss-topo:0.5122
# Epoch:560, P:None, Loss:155.7552, Loss-ae:155.1892, Loss-topo:0.5660
# Epoch:561, P:None, Loss:153.1628, Loss-ae:152.6296, Loss-topo:0.5332
# Epoch:562, P:None, Loss:151.6673, Loss-ae:151.1726, Loss-topo:0.4947
# Epoch:563, P:None, Loss:153.1642, Loss-ae:152.6808, Loss-topo:0.4834
# Epoch:564, P:None, Loss:153.8270, Loss-ae:153.3334, Loss-topo:0.4936
# Epoch:565, P:None, Loss:159.9659, Loss-ae:159.4590, Loss-topo:0.5069
# Epoch:566, P:None, Loss:154.9031, Loss-ae:154.4118, Loss-topo:0.4913
# Epoch:567, P:None, Loss:150.7272, Loss-ae:150.2557, Loss-topo:0.4715
# Epoch:568, P:None, Loss:154.4404, Loss-ae:153.9577, Loss-topo:0.4826
# Epoch:569, P:None, Loss:156.4974, Loss-ae:155.9516, Loss-topo:0.5458
# Epoch:570, P:None, Loss:154.8465, Loss-ae:154.3635, Loss-topo:0.4830
# Epoch:571, P:None, Loss:154.8925, Loss-ae:154.4033, Loss-topo:0.4892
# Epoch:572, P:None, Loss:155.8991, Loss-ae:155.4278, Loss-topo:0.4713
# Epoch:573, P:None, Loss:153.6018, Loss-ae:153.1080, Loss-topo:0.4938
# Epoch:574, P:None, Loss:153.7263, Loss-ae:153.2475, Loss-topo:0.4788
# Epoch:575, P:None, Loss:155.6423, Loss-ae:155.1397, Loss-topo:0.5026
# Epoch:576, P:None, Loss:154.1929, Loss-ae:153.6899, Loss-topo:0.5031
# Epoch:577, P:None, Loss:156.4571, Loss-ae:155.9758, Loss-topo:0.4812
# Epoch:578, P:None, Loss:152.7269, Loss-ae:152.2663, Loss-topo:0.4606
# Epoch:579, P:None, Loss:160.0552, Loss-ae:159.5588, Loss-topo:0.4965
# Epoch:580, P:None, Loss:148.5698, Loss-ae:148.1241, Loss-topo:0.4457
# Epoch:581, P:None, Loss:161.4183, Loss-ae:160.8994, Loss-topo:0.5189
# Epoch:582, P:None, Loss:154.4088, Loss-ae:153.9731, Loss-topo:0.4357
# Epoch:583, P:None, Loss:163.7596, Loss-ae:163.2907, Loss-topo:0.4689
# Epoch:584, P:None, Loss:153.9556, Loss-ae:153.4827, Loss-topo:0.4730
# Epoch:585, P:None, Loss:154.4524, Loss-ae:154.0137, Loss-topo:0.4388
# Epoch:586, P:None, Loss:160.7114, Loss-ae:160.2411, Loss-topo:0.4703
# Epoch:587, P:None, Loss:151.4836, Loss-ae:151.0608, Loss-topo:0.4228
# Epoch:588, P:None, Loss:147.9463, Loss-ae:147.5292, Loss-topo:0.4171
# Epoch:589, P:None, Loss:150.5051, Loss-ae:150.0980, Loss-topo:0.4071
# Epoch:590, P:None, Loss:155.9554, Loss-ae:155.4972, Loss-topo:0.4582
# Epoch:591, P:None, Loss:150.7321, Loss-ae:150.3355, Loss-topo:0.3966
# Epoch:592, P:None, Loss:154.3450, Loss-ae:153.9423, Loss-topo:0.4027
# Epoch:593, P:None, Loss:155.3464, Loss-ae:154.9345, Loss-topo:0.4120
# Epoch:594, P:None, Loss:155.2720, Loss-ae:154.8661, Loss-topo:0.4059
# Epoch:595, P:None, Loss:150.7332, Loss-ae:150.2939, Loss-topo:0.4392
# Epoch:596, P:None, Loss:150.5769, Loss-ae:150.1924, Loss-topo:0.3844
# Epoch:597, P:None, Loss:158.3532, Loss-ae:157.9045, Loss-topo:0.4487
# Epoch:598, P:None, Loss:149.5012, Loss-ae:149.1178, Loss-topo:0.3834
# Epoch:599, P:None, Loss:149.4917, Loss-ae:149.1000, Loss-topo:0.3917
# Epoch:600, P:None, Loss:153.0938, Loss-ae:152.6894, Loss-topo:0.4044
# Epoch:601, P:None, Loss:155.3055, Loss-ae:154.9057, Loss-topo:0.3997
# Epoch:602, P:None, Loss:156.8532, Loss-ae:156.4422, Loss-topo:0.4110
# Epoch:603, P:None, Loss:152.1077, Loss-ae:151.7241, Loss-topo:0.3836
# Epoch:604, P:None, Loss:152.3434, Loss-ae:151.9210, Loss-topo:0.4223
# Epoch:605, P:None, Loss:147.7428, Loss-ae:147.3475, Loss-topo:0.3953
# Epoch:606, P:None, Loss:158.3600, Loss-ae:157.9687, Loss-topo:0.3913
# Epoch:607, P:None, Loss:152.4056, Loss-ae:152.0065, Loss-topo:0.3991
# Epoch:608, P:None, Loss:154.6160, Loss-ae:154.2285, Loss-topo:0.3875
# Epoch:609, P:None, Loss:154.8019, Loss-ae:154.3842, Loss-topo:0.4177
# Epoch:610, P:None, Loss:156.0787, Loss-ae:155.6714, Loss-topo:0.4073
# Epoch:611, P:None, Loss:152.8175, Loss-ae:152.4480, Loss-topo:0.3695
# Epoch:612, P:None, Loss:153.7642, Loss-ae:153.3783, Loss-topo:0.3858
# Epoch:613, P:None, Loss:155.7597, Loss-ae:155.3787, Loss-topo:0.3809
# Epoch:614, P:None, Loss:152.3050, Loss-ae:151.9202, Loss-topo:0.3848
# Epoch:615, P:None, Loss:152.9774, Loss-ae:152.6061, Loss-topo:0.3713
# Epoch:616, P:None, Loss:154.2517, Loss-ae:153.8796, Loss-topo:0.3721
# Epoch:617, P:None, Loss:150.8852, Loss-ae:150.5198, Loss-topo:0.3654
# Epoch:618, P:None, Loss:149.3205, Loss-ae:148.9765, Loss-topo:0.3440
# Epoch:619, P:None, Loss:153.8442, Loss-ae:153.4814, Loss-topo:0.3628
# Epoch:620, P:None, Loss:151.0319, Loss-ae:150.6933, Loss-topo:0.3386
# Epoch:621, P:None, Loss:152.4645, Loss-ae:152.1054, Loss-topo:0.3591
# Epoch:622, P:None, Loss:152.4782, Loss-ae:152.1253, Loss-topo:0.3529
# Epoch:623, P:None, Loss:152.4993, Loss-ae:152.1388, Loss-topo:0.3605
# Epoch:624, P:None, Loss:150.3655, Loss-ae:150.0342, Loss-topo:0.3314
# Epoch:625, P:None, Loss:148.9642, Loss-ae:148.6291, Loss-topo:0.3351
# Epoch:626, P:None, Loss:158.9056, Loss-ae:158.5184, Loss-topo:0.3872
# Epoch:627, P:None, Loss:149.0577, Loss-ae:148.7313, Loss-topo:0.3264
# Epoch:628, P:None, Loss:151.5168, Loss-ae:151.1388, Loss-topo:0.3781
# Epoch:629, P:None, Loss:148.1038, Loss-ae:147.7792, Loss-topo:0.3246
# Epoch:630, P:None, Loss:150.6882, Loss-ae:150.3251, Loss-topo:0.3630
# Epoch:631, P:None, Loss:151.2163, Loss-ae:150.8916, Loss-topo:0.3247
# Epoch:632, P:None, Loss:155.1519, Loss-ae:154.7893, Loss-topo:0.3626
# Epoch:633, P:None, Loss:153.0671, Loss-ae:152.7412, Loss-topo:0.3259
# Epoch:634, P:None, Loss:153.2547, Loss-ae:152.9481, Loss-topo:0.3066
# Epoch:635, P:None, Loss:150.1298, Loss-ae:149.8186, Loss-topo:0.3112
# Epoch:636, P:None, Loss:149.3832, Loss-ae:149.0398, Loss-topo:0.3433
# Epoch:637, P:None, Loss:149.9826, Loss-ae:149.6456, Loss-topo:0.3370
# Epoch:638, P:None, Loss:154.8492, Loss-ae:154.5232, Loss-topo:0.3260
# Epoch:639, P:None, Loss:148.5803, Loss-ae:148.2762, Loss-topo:0.3042
# Epoch:640, P:None, Loss:147.8101, Loss-ae:147.5082, Loss-topo:0.3019
# Epoch:641, P:None, Loss:150.2187, Loss-ae:149.8551, Loss-topo:0.3636
# Epoch:642, P:None, Loss:153.9202, Loss-ae:153.6051, Loss-topo:0.3151
# Epoch:643, P:None, Loss:152.5511, Loss-ae:152.2485, Loss-topo:0.3026
# Epoch:644, P:None, Loss:147.9876, Loss-ae:147.7007, Loss-topo:0.2869
# Epoch:645, P:None, Loss:150.5838, Loss-ae:150.2696, Loss-topo:0.3142
# Epoch:646, P:None, Loss:147.0025, Loss-ae:146.7219, Loss-topo:0.2806
# Epoch:647, P:None, Loss:148.8862, Loss-ae:148.5910, Loss-topo:0.2953
# Epoch:648, P:None, Loss:145.2278, Loss-ae:144.9522, Loss-topo:0.2757
# Epoch:649, P:None, Loss:148.0545, Loss-ae:147.7941, Loss-topo:0.2604
# Epoch:650, P:None, Loss:145.3797, Loss-ae:145.0951, Loss-topo:0.2846
# Epoch:651, P:None, Loss:151.0598, Loss-ae:150.7671, Loss-topo:0.2927
# Epoch:652, P:None, Loss:147.6752, Loss-ae:147.3856, Loss-topo:0.2896
# Epoch:653, P:None, Loss:147.8144, Loss-ae:147.5517, Loss-topo:0.2628
# Epoch:654, P:None, Loss:148.3026, Loss-ae:148.0317, Loss-topo:0.2708
# Epoch:655, P:None, Loss:148.6234, Loss-ae:148.3122, Loss-topo:0.3112
# Epoch:656, P:None, Loss:148.0065, Loss-ae:147.7238, Loss-topo:0.2827
# Epoch:657, P:None, Loss:148.7655, Loss-ae:148.4715, Loss-topo:0.2940
# Epoch:658, P:None, Loss:146.7772, Loss-ae:146.5047, Loss-topo:0.2725
# Epoch:659, P:None, Loss:155.1446, Loss-ae:154.8678, Loss-topo:0.2768
# Epoch:660, P:None, Loss:145.9617, Loss-ae:145.6918, Loss-topo:0.2699
# Epoch:661, P:None, Loss:145.5177, Loss-ae:145.2508, Loss-topo:0.2668
# Epoch:662, P:None, Loss:153.5212, Loss-ae:153.2412, Loss-topo:0.2800
# Epoch:663, P:None, Loss:143.6189, Loss-ae:143.3597, Loss-topo:0.2592
# Epoch:664, P:None, Loss:148.8835, Loss-ae:148.6233, Loss-topo:0.2602
# Epoch:665, P:None, Loss:150.9136, Loss-ae:150.6365, Loss-topo:0.2771
# Epoch:666, P:None, Loss:150.2495, Loss-ae:149.9800, Loss-topo:0.2695
# Epoch:667, P:None, Loss:150.7352, Loss-ae:150.4805, Loss-topo:0.2547
# Epoch:668, P:None, Loss:148.6647, Loss-ae:148.4031, Loss-topo:0.2617
# Epoch:669, P:None, Loss:151.5055, Loss-ae:151.2372, Loss-topo:0.2683
# Epoch:670, P:None, Loss:145.5372, Loss-ae:145.3047, Loss-topo:0.2325
# Epoch:671, P:None, Loss:154.8286, Loss-ae:154.5836, Loss-topo:0.2449
# Epoch:672, P:None, Loss:147.5543, Loss-ae:147.3075, Loss-topo:0.2468
# Epoch:673, P:None, Loss:149.5517, Loss-ae:149.2885, Loss-topo:0.2632
# Epoch:674, P:None, Loss:146.6726, Loss-ae:146.4530, Loss-topo:0.2195
# Epoch:675, P:None, Loss:146.5986, Loss-ae:146.3666, Loss-topo:0.2321
# Epoch:676, P:None, Loss:156.7067, Loss-ae:156.4546, Loss-topo:0.2521
# Epoch:677, P:None, Loss:143.8676, Loss-ae:143.6423, Loss-topo:0.2253
# Epoch:678, P:None, Loss:147.8936, Loss-ae:147.6498, Loss-topo:0.2438
# Epoch:679, P:None, Loss:145.1573, Loss-ae:144.9364, Loss-topo:0.2208
# Epoch:680, P:None, Loss:146.8171, Loss-ae:146.5795, Loss-topo:0.2376
# Epoch:681, P:None, Loss:151.1380, Loss-ae:150.8931, Loss-topo:0.2449
# Epoch:682, P:None, Loss:150.8022, Loss-ae:150.5461, Loss-topo:0.2561
# Epoch:683, P:None, Loss:149.4147, Loss-ae:149.1964, Loss-topo:0.2183
# Epoch:684, P:None, Loss:145.7808, Loss-ae:145.5696, Loss-topo:0.2112
# Epoch:685, P:None, Loss:145.9130, Loss-ae:145.6728, Loss-topo:0.2402
# Epoch:686, P:None, Loss:149.2104, Loss-ae:148.9689, Loss-topo:0.2415
# Epoch:687, P:None, Loss:147.8444, Loss-ae:147.6154, Loss-topo:0.2290
# Epoch:688, P:None, Loss:142.5413, Loss-ae:142.3370, Loss-topo:0.2043
# Epoch:689, P:None, Loss:147.4337, Loss-ae:147.1887, Loss-topo:0.2450
# Epoch:690, P:None, Loss:145.5642, Loss-ae:145.3549, Loss-topo:0.2093
# Epoch:691, P:None, Loss:145.1404, Loss-ae:144.9232, Loss-topo:0.2172
# ...
# Epoch:1273, P:None, Loss:114.0387, Loss-ae:114.0293, Loss-topo:0.0094
# Epoch:1274, P:None, Loss:108.8216, Loss-ae:108.8133, Loss-topo:0.0083
# Epoch:1275, P:None, Loss:107.1027, Loss-ae:107.0948, Loss-topo:0.0080
# Epoch:1276, P:None, Loss:111.2459, Loss-ae:111.2375, Loss-topo:0.0084
# Epoch:1277, P:None, Loss:108.6431, Loss-ae:108.6335, Loss-topo:0.0096
# Epoch:1278, P:None, Loss:112.8523, Loss-ae:112.8432, Loss-topo:0.0091
# Epoch:1279, P:None, Loss:110.2492, Loss-ae:110.2415, Loss-topo:0.0077
# Epoch:1280, P:None, Loss:109.2247, Loss-ae:109.2158, Loss-topo:0.0089
# Epoch:1281, P:None, Loss:105.5498, Loss-ae:105.5427, Loss-topo:0.0071
# Epoch:1282, P:None, Loss:107.1549, Loss-ae:107.1470, Loss-topo:0.0080
# Epoch:1283, P:None, Loss:115.0325, Loss-ae:115.0236, Loss-topo:0.0089
# Epoch:1284, P:None, Loss:111.5810, Loss-ae:111.5707, Loss-topo:0.0103
# Epoch:1285, P:None, Loss:112.1254, Loss-ae:112.1175, Loss-topo:0.0079
# Epoch:1286, P:None, Loss:111.1036, Loss-ae:111.0962, Loss-topo:0.0075
# Epoch:1287, P:None, Loss:112.1803, Loss-ae:112.1704, Loss-topo:0.0099
# Epoch:1288, P:None, Loss:107.9675, Loss-ae:107.9602, Loss-topo:0.0073
# Epoch:1289, P:None, Loss:106.5553, Loss-ae:106.5483, Loss-topo:0.0071
# Epoch:1290, P:None, Loss:107.6452, Loss-ae:107.6373, Loss-topo:0.0078
# Epoch:1291, P:None, Loss:110.4350, Loss-ae:110.4274, Loss-topo:0.0076
# Epoch:1292, P:None, Loss:114.0232, Loss-ae:114.0146, Loss-topo:0.0086
# Epoch:1293, P:None, Loss:108.3055, Loss-ae:108.2967, Loss-topo:0.0087
# Epoch:1294, P:None, Loss:113.0972, Loss-ae:113.0873, Loss-topo:0.0099
# Epoch:1295, P:None, Loss:111.6934, Loss-ae:111.6841, Loss-topo:0.0093
# Epoch:1296, P:None, Loss:108.6999, Loss-ae:108.6930, Loss-topo:0.0070
# Epoch:1297, P:None, Loss:109.9633, Loss-ae:109.9560, Loss-topo:0.0072
# Epoch:1298, P:None, Loss:114.0782, Loss-ae:114.0698, Loss-topo:0.0084
# Epoch:1299, P:None, Loss:111.9572, Loss-ae:111.9505, Loss-topo:0.0068
# Epoch:1300, P:None, Loss:112.4920, Loss-ae:112.4841, Loss-topo:0.0079
# Epoch:1301, P:None, Loss:109.9390, Loss-ae:109.9312, Loss-topo:0.0078
# Epoch:1302, P:None, Loss:111.9318, Loss-ae:111.9242, Loss-topo:0.0076
# Epoch:1303, P:None, Loss:119.0880, Loss-ae:119.0784, Loss-topo:0.0095
# Epoch:1304, P:None, Loss:107.2528, Loss-ae:107.2464, Loss-topo:0.0064
# Epoch:1305, P:None, Loss:110.5507, Loss-ae:110.5441, Loss-topo:0.0066
# Epoch:1306, P:None, Loss:109.0866, Loss-ae:109.0798, Loss-topo:0.0068
# Epoch:1307, P:None, Loss:111.8054, Loss-ae:111.7980, Loss-topo:0.0074
# Epoch:1308, P:None, Loss:111.1015, Loss-ae:111.0936, Loss-topo:0.0079
# Epoch:1309, P:None, Loss:109.4977, Loss-ae:109.4912, Loss-topo:0.0064
# Epoch:1310, P:None, Loss:111.1190, Loss-ae:111.1121, Loss-topo:0.0068
# Epoch:1311, P:None, Loss:107.9850, Loss-ae:107.9791, Loss-topo:0.0059
# Epoch:1312, P:None, Loss:108.5359, Loss-ae:108.5302, Loss-topo:0.0057
# Epoch:1313, P:None, Loss:108.1324, Loss-ae:108.1253, Loss-topo:0.0071
# Epoch:1314, P:None, Loss:109.2514, Loss-ae:109.2439, Loss-topo:0.0075
# Epoch:1315, P:None, Loss:107.8754, Loss-ae:107.8694, Loss-topo:0.0060
# Epoch:1316, P:None, Loss:108.9849, Loss-ae:108.9788, Loss-topo:0.0061
# Epoch:1317, P:None, Loss:107.8283, Loss-ae:107.8211, Loss-topo:0.0073
# Epoch:1318, P:None, Loss:112.1068, Loss-ae:112.0996, Loss-topo:0.0072
# Epoch:1319, P:None, Loss:111.5175, Loss-ae:111.5104, Loss-topo:0.0070
# Epoch:1320, P:None, Loss:107.6679, Loss-ae:107.6615, Loss-topo:0.0064
# Epoch:1321, P:None, Loss:109.8610, Loss-ae:109.8546, Loss-topo:0.0064
# Epoch:1322, P:None, Loss:109.1097, Loss-ae:109.1036, Loss-topo:0.0060
# Epoch:1323, P:None, Loss:112.8064, Loss-ae:112.7990, Loss-topo:0.0074
# Epoch:1324, P:None, Loss:110.5704, Loss-ae:110.5634, Loss-topo:0.0070
# Epoch:1325, P:None, Loss:109.8456, Loss-ae:109.8395, Loss-topo:0.0061
# Epoch:1326, P:None, Loss:105.9554, Loss-ae:105.9487, Loss-topo:0.0066
# Epoch:1327, P:None, Loss:107.1666, Loss-ae:107.1602, Loss-topo:0.0063
# Epoch:1328, P:None, Loss:109.1091, Loss-ae:109.1030, Loss-topo:0.0061
# Epoch:1329, P:None, Loss:107.7258, Loss-ae:107.7184, Loss-topo:0.0074
# Epoch:1330, P:None, Loss:106.2359, Loss-ae:106.2288, Loss-topo:0.0071
# Epoch:1331, P:None, Loss:109.6451, Loss-ae:109.6379, Loss-topo:0.0072
# Epoch:1332, P:None, Loss:107.9051, Loss-ae:107.8991, Loss-topo:0.0060
# Epoch:1333, P:None, Loss:109.8032, Loss-ae:109.7971, Loss-topo:0.0061
# Epoch:1334, P:None, Loss:107.0184, Loss-ae:107.0119, Loss-topo:0.0065
# Epoch:1335, P:None, Loss:106.3588, Loss-ae:106.3530, Loss-topo:0.0058
# Epoch:1336, P:None, Loss:107.5771, Loss-ae:107.5707, Loss-topo:0.0064
# Epoch:1337, P:None, Loss:107.7072, Loss-ae:107.7005, Loss-topo:0.0066
# Epoch:1338, P:None, Loss:106.2141, Loss-ae:106.2083, Loss-topo:0.0058
# Epoch:1339, P:None, Loss:109.4135, Loss-ae:109.4083, Loss-topo:0.0052
# Epoch:1340, P:None, Loss:107.5338, Loss-ae:107.5284, Loss-topo:0.0054
# Epoch:1341, P:None, Loss:106.8112, Loss-ae:106.8059, Loss-topo:0.0053
# Epoch:1342, P:None, Loss:108.2604, Loss-ae:108.2541, Loss-topo:0.0063
# Epoch:1343, P:None, Loss:108.2866, Loss-ae:108.2804, Loss-topo:0.0062
# Epoch:1344, P:None, Loss:105.2762, Loss-ae:105.2699, Loss-topo:0.0063
# Epoch:1345, P:None, Loss:109.5749, Loss-ae:109.5694, Loss-topo:0.0054
# Epoch:1346, P:None, Loss:110.3582, Loss-ae:110.3514, Loss-topo:0.0068
# Epoch:1347, P:None, Loss:108.1360, Loss-ae:108.1304, Loss-topo:0.0056
# Epoch:1348, P:None, Loss:111.2560, Loss-ae:111.2502, Loss-topo:0.0058
# Epoch:1349, P:None, Loss:108.3775, Loss-ae:108.3719, Loss-topo:0.0056
# Epoch:1350, P:None, Loss:107.7953, Loss-ae:107.7902, Loss-topo:0.0051
# Epoch:1351, P:None, Loss:112.4924, Loss-ae:112.4862, Loss-topo:0.0062
# Epoch:1352, P:None, Loss:106.9509, Loss-ae:106.9449, Loss-topo:0.0060
# Epoch:1353, P:None, Loss:108.5898, Loss-ae:108.5842, Loss-topo:0.0055
# Epoch:1354, P:None, Loss:109.5489, Loss-ae:109.5442, Loss-topo:0.0047
# Epoch:1355, P:None, Loss:107.7282, Loss-ae:107.7231, Loss-topo:0.0051
# Epoch:1356, P:None, Loss:108.1989, Loss-ae:108.1941, Loss-topo:0.0049
# Epoch:1357, P:None, Loss:111.6806, Loss-ae:111.6745, Loss-topo:0.0061
# Epoch:1358, P:None, Loss:109.8404, Loss-ae:109.8348, Loss-topo:0.0056
# Epoch:1359, P:None, Loss:105.8820, Loss-ae:105.8769, Loss-topo:0.0051
# Epoch:1360, P:None, Loss:106.6008, Loss-ae:106.5958, Loss-topo:0.0051
# Epoch:1361, P:None, Loss:103.8750, Loss-ae:103.8707, Loss-topo:0.0043
# Epoch:1362, P:None, Loss:111.8237, Loss-ae:111.8175, Loss-topo:0.0063
# Epoch:1363, P:None, Loss:109.2201, Loss-ae:109.2152, Loss-topo:0.0049
# Epoch:1364, P:None, Loss:104.3306, Loss-ae:104.3262, Loss-topo:0.0044
# Epoch:1365, P:None, Loss:109.8751, Loss-ae:109.8696, Loss-topo:0.0054
# Epoch:1366, P:None, Loss:107.8948, Loss-ae:107.8908, Loss-topo:0.0040
# Epoch:1367, P:None, Loss:110.8080, Loss-ae:110.8026, Loss-topo:0.0054
# Epoch:1368, P:None, Loss:111.0679, Loss-ae:111.0613, Loss-topo:0.0067
# Epoch:1369, P:None, Loss:107.3480, Loss-ae:107.3428, Loss-topo:0.0052
# Epoch:1370, P:None, Loss:111.5850, Loss-ae:111.5787, Loss-topo:0.0064
# Epoch:1371, P:None, Loss:106.1443, Loss-ae:106.1390, Loss-topo:0.0054
# Epoch:1372, P:None, Loss:105.6946, Loss-ae:105.6895, Loss-topo:0.0051
# Epoch:1373, P:None, Loss:109.1861, Loss-ae:109.1805, Loss-topo:0.0056
# Epoch:1374, P:None, Loss:109.6811, Loss-ae:109.6766, Loss-topo:0.0044
# Epoch:1375, P:None, Loss:108.0902, Loss-ae:108.0851, Loss-topo:0.0051
# Epoch:1376, P:None, Loss:108.4488, Loss-ae:108.4432, Loss-topo:0.0056
# Epoch:1377, P:None, Loss:107.0179, Loss-ae:107.0122, Loss-topo:0.0058
# Epoch:1378, P:None, Loss:109.6023, Loss-ae:109.5971, Loss-topo:0.0053
# Epoch:1379, P:None, Loss:108.4288, Loss-ae:108.4239, Loss-topo:0.0049
# Epoch:1380, P:None, Loss:107.7505, Loss-ae:107.7454, Loss-topo:0.0052
# Epoch:1381, P:None, Loss:105.6722, Loss-ae:105.6674, Loss-topo:0.0048
# Epoch:1382, P:None, Loss:107.0750, Loss-ae:107.0697, Loss-topo:0.0052
# Epoch:1383, P:None, Loss:106.3692, Loss-ae:106.3636, Loss-topo:0.0056
# Epoch:1384, P:None, Loss:108.7146, Loss-ae:108.7105, Loss-topo:0.0041
# Epoch:1385, P:None, Loss:109.9279, Loss-ae:109.9225, Loss-topo:0.0054
# Epoch:1386, P:None, Loss:107.4901, Loss-ae:107.4849, Loss-topo:0.0052
# Epoch:1387, P:None, Loss:107.4334, Loss-ae:107.4289, Loss-topo:0.0045
# Epoch:1388, P:None, Loss:105.7817, Loss-ae:105.7760, Loss-topo:0.0056
# Epoch:1389, P:None, Loss:109.2577, Loss-ae:109.2525, Loss-topo:0.0053
# Epoch:1390, P:None, Loss:105.0778, Loss-ae:105.0724, Loss-topo:0.0054
# Epoch:1391, P:None, Loss:107.9955, Loss-ae:107.9906, Loss-topo:0.0048
# Epoch:1392, P:None, Loss:106.8896, Loss-ae:106.8841, Loss-topo:0.0055
# Epoch:1393, P:None, Loss:105.0682, Loss-ae:105.0632, Loss-topo:0.0050
# Epoch:1394, P:None, Loss:110.4419, Loss-ae:110.4380, Loss-topo:0.0039
# Epoch:1395, P:None, Loss:108.8366, Loss-ae:108.8322, Loss-topo:0.0044
# Epoch:1396, P:None, Loss:105.7605, Loss-ae:105.7568, Loss-topo:0.0037
# Epoch:1397, P:None, Loss:107.4873, Loss-ae:107.4823, Loss-topo:0.0050
# Epoch:1398, P:None, Loss:109.3892, Loss-ae:109.3838, Loss-topo:0.0054
# Epoch:1399, P:None, Loss:107.8855, Loss-ae:107.8813, Loss-topo:0.0042
# Epoch:1400, P:None, Loss:110.2898, Loss-ae:110.2846, Loss-topo:0.0052
# Epoch:1401, P:None, Loss:110.8248, Loss-ae:110.8203, Loss-topo:0.0045
# Epoch:1402, P:None, Loss:110.1378, Loss-ae:110.1331, Loss-topo:0.0047
# Epoch:1403, P:None, Loss:108.9689, Loss-ae:108.9636, Loss-topo:0.0053
# Epoch:1404, P:None, Loss:104.2905, Loss-ae:104.2859, Loss-topo:0.0046
# Epoch:1405, P:None, Loss:109.2145, Loss-ae:109.2109, Loss-topo:0.0036
# Epoch:1406, P:None, Loss:106.1947, Loss-ae:106.1896, Loss-topo:0.0051
# Epoch:1407, P:None, Loss:107.0773, Loss-ae:107.0736, Loss-topo:0.0037
# Epoch:1408, P:None, Loss:109.4889, Loss-ae:109.4835, Loss-topo:0.0053
# Epoch:1409, P:None, Loss:109.7386, Loss-ae:109.7339, Loss-topo:0.0047
# Epoch:1410, P:None, Loss:109.2720, Loss-ae:109.2680, Loss-topo:0.0040
# Epoch:1411, P:None, Loss:108.9654, Loss-ae:108.9615, Loss-topo:0.0039
# Epoch:1412, P:None, Loss:108.7876, Loss-ae:108.7827, Loss-topo:0.0049
# Epoch:1413, P:None, Loss:104.5427, Loss-ae:104.5383, Loss-topo:0.0044
# Epoch:1414, P:None, Loss:106.6050, Loss-ae:106.6011, Loss-topo:0.0039
# Epoch:1415, P:None, Loss:106.9651, Loss-ae:106.9614, Loss-topo:0.0036
# Epoch:1416, P:None, Loss:109.8992, Loss-ae:109.8947, Loss-topo:0.0046
# Epoch:1417, P:None, Loss:106.0657, Loss-ae:106.0616, Loss-topo:0.0041
# Epoch:1418, P:None, Loss:110.9863, Loss-ae:110.9817, Loss-topo:0.0046
# Epoch:1419, P:None, Loss:105.3293, Loss-ae:105.3247, Loss-topo:0.0046
# Epoch:1420, P:None, Loss:106.5270, Loss-ae:106.5233, Loss-topo:0.0036
# Epoch:1421, P:None, Loss:107.1669, Loss-ae:107.1630, Loss-topo:0.0038
# Epoch:1422, P:None, Loss:107.5852, Loss-ae:107.5800, Loss-topo:0.0051
# Epoch:1423, P:None, Loss:105.5029, Loss-ae:105.4987, Loss-topo:0.0042
# Epoch:1424, P:None, Loss:106.9327, Loss-ae:106.9291, Loss-topo:0.0036
# Epoch:1425, P:None, Loss:106.4268, Loss-ae:106.4223, Loss-topo:0.0045
# Epoch:1426, P:None, Loss:106.9728, Loss-ae:106.9678, Loss-topo:0.0051
# Epoch:1427, P:None, Loss:106.0338, Loss-ae:106.0298, Loss-topo:0.0039
# Epoch:1428, P:None, Loss:108.3327, Loss-ae:108.3284, Loss-topo:0.0044
# Epoch:1429, P:None, Loss:111.9668, Loss-ae:111.9622, Loss-topo:0.0046
# Epoch:1430, P:None, Loss:105.2573, Loss-ae:105.2537, Loss-topo:0.0036
# Epoch:1431, P:None, Loss:106.0503, Loss-ae:106.0464, Loss-topo:0.0039
# Epoch:1432, P:None, Loss:107.1907, Loss-ae:107.1862, Loss-topo:0.0046
# Epoch:1433, P:None, Loss:109.5807, Loss-ae:109.5759, Loss-topo:0.0049
# Epoch:1434, P:None, Loss:106.9258, Loss-ae:106.9220, Loss-topo:0.0038
# Epoch:1435, P:None, Loss:108.1746, Loss-ae:108.1702, Loss-topo:0.0044
# Epoch:1436, P:None, Loss:106.7377, Loss-ae:106.7340, Loss-topo:0.0037
# Epoch:1437, P:None, Loss:107.2326, Loss-ae:107.2291, Loss-topo:0.0034
# Epoch:1438, P:None, Loss:112.0581, Loss-ae:112.0539, Loss-topo:0.0042
# Epoch:1439, P:None, Loss:109.4822, Loss-ae:109.4774, Loss-topo:0.0048
# Epoch:1440, P:None, Loss:104.5734, Loss-ae:104.5683, Loss-topo:0.0051
# Epoch:1441, P:None, Loss:108.8431, Loss-ae:108.8383, Loss-topo:0.0048
# Epoch:1442, P:None, Loss:105.4943, Loss-ae:105.4906, Loss-topo:0.0037
# Epoch:1443, P:None, Loss:104.4172, Loss-ae:104.4140, Loss-topo:0.0031
# Epoch:1444, P:None, Loss:107.2608, Loss-ae:107.2577, Loss-topo:0.0031
# Epoch:1445, P:None, Loss:109.7625, Loss-ae:109.7586, Loss-topo:0.0038
# Epoch:1446, P:None, Loss:108.8484, Loss-ae:108.8445, Loss-topo:0.0040
# Epoch:1447, P:None, Loss:109.4407, Loss-ae:109.4368, Loss-topo:0.0039
# Epoch:1448, P:None, Loss:107.7500, Loss-ae:107.7459, Loss-topo:0.0041
# Epoch:1449, P:None, Loss:104.2090, Loss-ae:104.2059, Loss-topo:0.0031
# Epoch:1450, P:None, Loss:106.9603, Loss-ae:106.9565, Loss-topo:0.0038
# Epoch:1451, P:None, Loss:106.0936, Loss-ae:106.0892, Loss-topo:0.0044
# Epoch:1452, P:None, Loss:106.6178, Loss-ae:106.6122, Loss-topo:0.0056
# Epoch:1453, P:None, Loss:107.6820, Loss-ae:107.6778, Loss-topo:0.0043
# Epoch:1454, P:None, Loss:105.2918, Loss-ae:105.2879, Loss-topo:0.0039
# Epoch:1455, P:None, Loss:111.5208, Loss-ae:111.5167, Loss-topo:0.0040
# Epoch:1456, P:None, Loss:105.2984, Loss-ae:105.2950, Loss-topo:0.0033
# Epoch:1457, P:None, Loss:110.5276, Loss-ae:110.5242, Loss-topo:0.0034
# Epoch:1458, P:None, Loss:106.7139, Loss-ae:106.7102, Loss-topo:0.0037
# Epoch:1459, P:None, Loss:103.4201, Loss-ae:103.4160, Loss-topo:0.0041
# Epoch:1460, P:None, Loss:109.7440, Loss-ae:109.7408, Loss-topo:0.0032
# Epoch:1461, P:None, Loss:108.8946, Loss-ae:108.8909, Loss-topo:0.0037
# Epoch:1462, P:None, Loss:108.6242, Loss-ae:108.6203, Loss-topo:0.0039
# Epoch:1463, P:None, Loss:103.5096, Loss-ae:103.5059, Loss-topo:0.0037
# Epoch:1464, P:None, Loss:110.4375, Loss-ae:110.4336, Loss-topo:0.0039
# Epoch:1465, P:None, Loss:107.5461, Loss-ae:107.5417, Loss-topo:0.0044
# Epoch:1466, P:None, Loss:112.3074, Loss-ae:112.3032, Loss-topo:0.0042
# Epoch:1467, P:None, Loss:111.0736, Loss-ae:111.0694, Loss-topo:0.0042
# Epoch:1468, P:None, Loss:107.2018, Loss-ae:107.1970, Loss-topo:0.0047
# Epoch:1469, P:None, Loss:105.2377, Loss-ae:105.2343, Loss-topo:0.0034
# Epoch:1470, P:None, Loss:110.3380, Loss-ae:110.3348, Loss-topo:0.0032
# Epoch:1471, P:None, Loss:106.5366, Loss-ae:106.5329, Loss-topo:0.0037
# Epoch:1472, P:None, Loss:106.7299, Loss-ae:106.7266, Loss-topo:0.0033
# Epoch:1473, P:None, Loss:108.2692, Loss-ae:108.2657, Loss-topo:0.0036
# Epoch:1474, P:None, Loss:105.1596, Loss-ae:105.1553, Loss-topo:0.0043
# Epoch:1475, P:None, Loss:108.7042, Loss-ae:108.7013, Loss-topo:0.0029
# Epoch:1476, P:None, Loss:109.9849, Loss-ae:109.9809, Loss-topo:0.0040
# Epoch:1477, P:None, Loss:107.8355, Loss-ae:107.8321, Loss-topo:0.0034
# Epoch:1478, P:None, Loss:107.7039, Loss-ae:107.7007, Loss-topo:0.0032
# Epoch:1479, P:None, Loss:105.6192, Loss-ae:105.6154, Loss-topo:0.0038
# Epoch:1480, P:None, Loss:107.5133, Loss-ae:107.5101, Loss-topo:0.0032
# Epoch:1481, P:None, Loss:108.8388, Loss-ae:108.8349, Loss-topo:0.0039
# Epoch:1482, P:None, Loss:106.9059, Loss-ae:106.9024, Loss-topo:0.0035
# Epoch:1483, P:None, Loss:108.8972, Loss-ae:108.8936, Loss-topo:0.0036
# Epoch:1484, P:None, Loss:106.7465, Loss-ae:106.7426, Loss-topo:0.0040
# Epoch:1485, P:None, Loss:107.9238, Loss-ae:107.9204, Loss-topo:0.0033
# Epoch:1486, P:None, Loss:107.4874, Loss-ae:107.4836, Loss-topo:0.0038
# Epoch:1487, P:None, Loss:107.5947, Loss-ae:107.5916, Loss-topo:0.0031
# Epoch:1488, P:None, Loss:108.6663, Loss-ae:108.6630, Loss-topo:0.0033
# Epoch:1489, P:None, Loss:107.8805, Loss-ae:107.8764, Loss-topo:0.0041
# Epoch:1490, P:None, Loss:111.3447, Loss-ae:111.3407, Loss-topo:0.0041
# Epoch:1491, P:None, Loss:109.4749, Loss-ae:109.4712, Loss-topo:0.0037
# Epoch:1492, P:None, Loss:109.2534, Loss-ae:109.2495, Loss-topo:0.0039
# Epoch:1493, P:None, Loss:107.4259, Loss-ae:107.4225, Loss-topo:0.0034
# Epoch:1494, P:None, Loss:106.9467, Loss-ae:106.9437, Loss-topo:0.0030
# Epoch:1495, P:None, Loss:107.2530, Loss-ae:107.2495, Loss-topo:0.0035
# Epoch:1496, P:None, Loss:104.2138, Loss-ae:104.2103, Loss-topo:0.0034
# Epoch:1497, P:None, Loss:109.3597, Loss-ae:109.3565, Loss-topo:0.0032
# Epoch:1498, P:None, Loss:108.9379, Loss-ae:108.9348, Loss-topo:0.0031
# Epoch:1499, P:None, Loss:107.6696, Loss-ae:107.6669, Loss-topo:0.0027
# Epoch:1500, P:None, Loss:109.6582, Loss-ae:109.6546, Loss-topo:0.0036

# %%
train_LD = topo_reducer.transform(train_HD)
test_LD = topo_reducer.transform(test_HD)

# %%
train_LD = np.reshape(topo_reducer.transform(train_HD), (-1, model_dim))
print('TRAIN LD RESHAPED', train_LD.shape)
test_LD = np.reshape(topo_reducer.transform(test_HD), (-1, model_dim))
print('TEST LD RESHAPED', test_LD.shape)
# Out:
# TRAIN LD RESHAPED (4020, 10)
# TEST LD RESHAPED (1020, 10)

# %%
experiments_result = run_experiments(train_HD, train_LD, train_Y, test_HD, test_LD, test_Y)
experiments_result
# Out:
# {'RF-ACC': 0.8299999999999998,
#  'RF-F1': 0.8273908973825199,
#  'SVC-ACC': 0.8931372549019608,
#  'SVC-F1': 0.8928722407029736,
#  'KNN-ACC': 0.7852941176470588,
#  'KNN-F1': 0.7822274501881106}

# %%
# Visualizing
tsne = TSNE()
test_2D = tsne.fit_transform(test_LD)
visualize(test_2D, test_Y)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %% [markdown]
# # Reducing with Topological Autoencoders (L=1)

# %%
model_lam = 1
topo_reducer = CustomTopoDimRedTransform(
    model_name='DeepAE_custom_dim2',
    model_lambda=model_lam,
    patience=None,
    num_epochs=model_epc,
    from_dim=180,
    to_dim=model_dim
)
# Out:
# Topologically Regularized DeepAE_custom_dim2
# Using python to compute signatures
# DeepAE_custom_dim, Input: (1, 180) Inner dim: 10

# %%
title_plot = "MotionSense 20Hz\nTopoAE lambda {}".format(model_lam)
topo_reducer.fit(train_HD, train_Y, title_plot=title_plot)
# Out:
# Epoch:1, P:None, Loss:2237.5375, Loss-ae:2226.8250, Loss-topo:10.7125
# Epoch:2, P:None, Loss:2151.6718, Loss-ae:2150.3993, Loss-topo:1.2726
# Epoch:3, P:None, Loss:743.8149, Loss-ae:736.2469, Loss-topo:7.5681
# Epoch:4, P:None, Loss:628.1425, Loss-ae:623.4656, Loss-topo:4.6769
# Epoch:5, P:None, Loss:544.3499, Loss-ae:537.7568, Loss-topo:6.5931
# Epoch:6, P:None, Loss:510.8661, Loss-ae:505.2107, Loss-topo:5.6554
# Epoch:7, P:None, Loss:475.0273, Loss-ae:471.6480, Loss-topo:3.3793
# Epoch:8, P:None, Loss:329.8885, Loss-ae:320.5318, Loss-topo:9.3567
# Epoch:9, P:None, Loss:296.6618, Loss-ae:291.8277, Loss-topo:4.8340
# Epoch:10, P:None, Loss:301.5856, Loss-ae:297.2778, Loss-topo:4.3078
# Epoch:11, P:None, Loss:264.0216, Loss-ae:258.9578, Loss-topo:5.0638
# Epoch:12, P:None, Loss:244.8668, Loss-ae:240.5951, Loss-topo:4.2718
# Epoch:13, P:None, Loss:259.7724, Loss-ae:253.2849, Loss-topo:6.4875
# Epoch:14, P:None, Loss:202.2862, Loss-ae:193.3861, Loss-topo:8.9001
# Epoch:15, P:None, Loss:177.4735, Loss-ae:170.1982, Loss-topo:7.2754
# Epoch:16, P:None, Loss:171.4234, Loss-ae:165.7369, Loss-topo:5.6864
# Epoch:17, P:None, Loss:165.9261, Loss-ae:160.7790, Loss-topo:5.1470
# Epoch:18, P:None, Loss:164.4181, Loss-ae:159.6750, Loss-topo:4.7431
# Epoch:19, P:None, Loss:158.1469, Loss-ae:153.9962, Loss-topo:4.1507
# Epoch:20, P:None, Loss:157.2531, Loss-ae:153.0825, Loss-topo:4.1706
# Epoch:21, P:None, Loss:158.7865, Loss-ae:153.9498, Loss-topo:4.8367
# Epoch:22, P:None, Loss:147.1395, Loss-ae:143.4351, Loss-topo:3.7044
# Epoch:23, P:None, Loss:147.3811, Loss-ae:143.2111, Loss-topo:4.1700
# Epoch:24, P:None, Loss:143.8821, Loss-ae:140.3583, Loss-topo:3.5239
# Epoch:25, P:None, Loss:151.5663, Loss-ae:148.2211, Loss-topo:3.3453
# Epoch:26, P:None, Loss:148.3162, Loss-ae:145.1279, Loss-topo:3.1883
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [26], in <cell line: 2>()
#       1 title_plot = "MotionSense 20Hz\nTopoAE lambda {}".format(model_lam)
# ----> 2 topo_reducer.fit(train_HD, train_Y, title_plot=title_plot)
#
# File ~/librep-hiaac/experiments/Topological_ae/MotionSense20Hz/../../../librep/transforms/topo_ae.py:73, in TopologicalDimensionalityReduction.fit(self, X, y, title_plot)
#      71 loss, loss_components = self.model(in_tensor)
#      72 self.optimizer.zero_grad()
# ---> 73 loss.backward()
#      74 self.optimizer.step()
#      75 epoch_train_loss.append(loss.item())
#
# File /usr/local/lib/python3.8/dist-packages/torch/_tensor.py:484, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     474 if has_torch_function_unary(self):
#     475     return handle_torch_function(
#     476         Tensor.backward,
#     477         (self,),
#    (...)
#     482         inputs=inputs,
#     483     )
# --> 484 torch.autograd.backward(
#     485     self, gradient, retain_graph, create_graph, inputs=inputs
#     486 )
#
# File /usr/local/lib/python3.8/dist-packages/torch/autograd/__init__.py:191, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     186     retain_graph = create_graph
#     188 # The reason we repeat same the comment below is that
#     189 # some Python versions print out the first line of a multi-line function
#     190 # calls in the traceback and some print out the last line
# --> 191 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     192     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     193     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
train_LD = topo_reducer.transform(train_HD)
test_LD = topo_reducer.transform(test_HD)

# %%
train_LD = np.reshape(topo_reducer.transform(train_HD), (-1, model_dim))
print('TRAIN LD RESHAPED', train_LD.shape)
test_LD = np.reshape(topo_reducer.transform(test_HD), (-1, model_dim))
print('TEST LD RESHAPED', test_LD.shape)

# %%
experiments_result = run_experiments(train_HD, train_LD, train_Y, test_HD, test_LD, test_Y)
experiments_result

# %%
# Visualizing
tsne = TSNE()
test_2D = tsne.fit_transform(test_LD)
visualize(test_2D, test_Y)

# %% [markdown]
# # Reducing with Topological Autoencoders (L=5)

# %%
model_lam = 5
topo_reducer = CustomTopoDimRedTransform(
    model_name='DeepAE_custom_dim2',
    model_lambda=model_lam,
    patience=None,
    num_epochs=model_epc,
    from_dim=180,
    to_dim=model_dim
)

# %%
title_plot = "MotionSense 20Hz\nTopoAE lambda {}".format(model_lam)
topo_reducer.fit(train_HD, train_Y, title_plot=title_plot)

# %%
train_LD = topo_reducer.transform(train_HD)
test_LD = topo_reducer.transform(test_HD)

# %%
train_LD = np.reshape(topo_reducer.transform(train_HD), (-1, model_dim))
print('TRAIN LD RESHAPED', train_LD.shape)
test_LD = np.reshape(topo_reducer.transform(test_HD), (-1, model_dim))
print('TEST LD RESHAPED', test_LD.shape)

# %%
experiments_result = run_experiments(train_HD, train_LD, train_Y, test_HD, test_LD, test_Y)
experiments_result

# %%
# Visualizing
tsne = TSNE()
test_2D = tsne.fit_transform(test_LD)
visualize(test_2D, test_Y)

# %% [markdown]
# # Reducing with Topological Autoencoders (L=10)

# %%
model_lam = 10
topo_reducer = CustomTopoDimRedTransform(
    model_name='DeepAE_custom_dim2',
    model_lambda=model_lam,
    patience=None,
    num_epochs=model_epc,
    from_dim=180,
    to_dim=model_dim
)

# %%
title_plot = "MotionSense 20Hz\nTopoAE lambda {}".format(model_lam)
topo_reducer.fit(train_HD, train_Y, title_plot=title_plot)

# %%
train_LD = topo_reducer.transform(train_HD)
test_LD = topo_reducer.transform(test_HD)

# %%
train_LD = np.reshape(topo_reducer.transform(train_HD), (-1, model_dim))
print('TRAIN LD RESHAPED', train_LD.shape)
test_LD = np.reshape(topo_reducer.transform(test_HD), (-1, model_dim))
print('TEST LD RESHAPED', test_LD.shape)

# %%
experiments_result = run_experiments(train_HD, train_LD, train_Y, test_HD, test_LD, test_Y)
experiments_result

# %%
# Visualizing
tsne = TSNE()
test_2D = tsne.fit_transform(test_LD)
visualize(test_2D, test_Y)

# %% [markdown]
# # Reducing with Topological Autoencoders (L=100)

# %%
model_lam = 100
topo_reducer = CustomTopoDimRedTransform(
    model_name='DeepAE_custom_dim2',
    model_lambda=model_lam,
    patience=None,
    num_epochs=model_epc,
    from_dim=180,
    to_dim=model_dim
)

# %%
title_plot = "MotionSense 20Hz\nTopoAE lambda {}".format(model_lam)
topo_reducer.fit(train_HD, train_Y, title_plot=title_plot)

# %%
train_LD = topo_reducer.transform(train_HD)
test_LD = topo_reducer.transform(test_HD)

# %%
train_LD = np.reshape(topo_reducer.transform(train_HD), (-1, model_dim))
print('TRAIN LD RESHAPED', train_LD.shape)
test_LD = np.reshape(topo_reducer.transform(test_HD), (-1, model_dim))
print('TEST LD RESHAPED', test_LD.shape)

# %%
experiments_result = run_experiments(train_HD, train_LD, train_Y, test_HD, test_LD, test_Y)
experiments_result

# %%
# Visualizing
tsne = TSNE()
test_2D = tsne.fit_transform(test_LD)
visualize(test_2D, test_Y)

# %%
# Reducing with Convolutional Topological Autoencoders

# %%
# model_lam = 1
# model_dim = 10
# model_epc = 200
# topo_reducer = TopologicalDimensionalityReduction(
#     ae_model='ConvolutionalAutoencoder_custom_dim',
#     lam = model_lam,
#     ae_kwargs = {'input_dims':(1, 360), 'custom_dim':model_dim},
#     input_shape = (-1, 1, 1, 360),
#     patience = None,
#     num_epochs = model_epc
# )

# %%
# title_plot = "MotionSense 20Hz\nTopoAE lambda {}".format(model_lam)
# topo_reducer.fit(train_HD, train_Y, title_plot=title_plot)

# %%
# train_LD = topo_reducer.transform(train_HD)
# test_LD = topo_reducer.transform(test_HD)

# %%
# train_LD = np.reshape(topo_reducer.transform(train_HD), (-1, model_dim))
# print('TRAIN LD RESHAPED', train_LD.shape)
# test_LD = np.reshape(topo_reducer.transform(test_HD), (-1, model_dim))
# print('TEST LD RESHAPED', test_LD.shape)

# %%
# experiments_result = run_experiments(train_HD, train_LD, train_Y, test_HD, test_LD, test_Y)
# experiments_result
